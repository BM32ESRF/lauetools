# %%
import LaueTools as LT

# %%
LT.__file__
# Out:
# '/home/micha/lauetoolsgithub/LaueTools/__init__.py'

# %%
import LaueTools.dict_LaueTools as DictLT
# Out:
# loading lauetools_config.json in  /home/micha/lauetoolsgithub/LaueTools
# No user materials.yaml found. Using default materials.yaml
# loading lauetools_config.json in  /home/micha/lauetoolsgithub/LaueTools
# No user materials.yaml found. Using default materials.yaml

# %%
dd =DictLT.dict_Materials

# %%
'Zr_ref2' in dd
# Out:
# False
