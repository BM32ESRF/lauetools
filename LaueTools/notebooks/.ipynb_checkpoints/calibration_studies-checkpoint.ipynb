# %% [markdown]
# # read results of calibration

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import LaueTools.IOLaueTools as IOLT

# %%
folder = '/home/micha/lauetoolsgithub/LaueTools/Examples/Ge/'
os.listdir(folder)
# Out:
# ['calib_.dat',
#  'modifcalib.det',
#  'Ge0001.cor',
#  'defaultGe0001.cor',
#  'calib_.cor',
#  'Ge0001calib.det',
#  'dat_Ge0001_fitnb_1_normal.fit',
#  'normalcalib.det',
#  'Ge0001.dat',
#  'Ge0001.fit',
#  'dat_Ge0001_0.irp',
#  'dat_Ge0001.cor',
#  'dat_Ge0001_fitnb_1.fit']

# %%
filename = 'dat_Ge0001_fitnb_1_normal.fit'
_res = IOLT.readfile_fit(os.path.join(folder, filename), return_columnheaders=True)  
res, dicocol = _res
print('dicocol',dicocol)
# Out:
# got a grain!
# iline =5 line #Number of indexed spots: 83
#
# Eulers Angles found 1
# dicocol {'spot_index': 0, 'Intensity': 1, 'h': 2, 'k': 3, 'l': 4, 'pixDev': 5, 'energy(keV)': 6, 'Xexp': 7, 'Yexp': 8, '2theta_exp': 9, 'chi_exp': 10, 'Xtheo': 11, 'Ytheo': 12, '2theta_theo': 13, 'chi_theo': 14, 'Qx': 15, 'Qy': 16, 'Qz': 17}

# %%
spotsdata = res[4]
Xexp, Yexp=spotsdata[:,7:9].T
Xtheo, Ytheo=spotsdata[:,11:13].T
E = spotsdata[:,6]
h,k,l = spotsdata[:,1:4].T
pixdev = spotsdata[:,5]
Intensity = spotsdata[:,1]

# %%
dX, dY = Xexp-Xtheo,Yexp-Ytheo

fig3, ax3 =plt.subplots()
ax3.bar(E, dY)
ax3.scatter(E, dY)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig4, ax4 =plt.subplots()
ax4.bar(E, pixdev)
ax4.scatter(E, pixdev)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig5, ax5 =plt.subplots()
#ax5.bar(dY, Intensity)
pp = ax5.scatter(dY, Intensity, c=E, cmap='hot')
plt.colorbar(pp)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig6, ax6=plt.subplots()
#ax5.bar(dY, Intensity)
pp = ax6.scatter(E, Intensity, c=E, cmap='hot')
plt.colorbar(pp)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.cm as cm
import matplotlib



fig, ax =plt.subplots()
ax.scatter(Xexp,Yexp)

fig2, ax2 =plt.subplots()
ax2.scatter(Xexp,Yexp, c=E, cmap='hot')
ax2.quiver(Xexp,Yexp,dX, dY,E, cmap='hot')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
spotsdata
# Out:
# array([[ 5.900000e+01,  1.576400e+03,  3.000000e+00, ..., -6.118560e-01,
#         -1.879630e-01,  4.289020e-01],
#        [ 4.600000e+01,  2.377760e+03,  5.000000e+00, ..., -9.558140e-01,
#         -1.084840e-01,  4.101190e-01],
#        [ 8.000000e+00,  1.331881e+04,  3.000000e+00, ..., -6.866890e-01,
#         -4.622310e-01,  6.390590e-01],
#        ...,
#        [ 6.400000e+01,  1.331830e+03,  6.000000e+00, ..., -9.760650e-01,
#          7.979140e-01,  1.288531e+00],
#        [ 6.800000e+01,  1.105270e+03,  1.000000e+01, ..., -1.663980e+00,
#          9.568730e-01,  1.250966e+00],
#        [ 5.800000e+01,  1.591710e+03,  8.000000e+00, ..., -1.394856e+00,
#          6.031260e-01,  1.479905e+00]], dtype=float32)

# %% [markdown]
# ![title](img/Geattenuation.png)

# %%
def Ge_attenuation(E): # in micron
    return np.where(E<11., (66-10)/6*(E-5)+10, (60-10)/11*(E-11)+10)

erange = np.arange(5,22,.1)
fig, ax =plt.subplots()
ax.scatter(erange,Ge_attenuation(erange))
# Out:
# <img src="data:image/png;base64,..." width="420.6666666666667">

# %%
# correction in y pixel 
-Ge_attenuation(erange)/1000./0.079142
# Out:
# array([-0.136239782016349, -0.148955495004541, -0.161671207992734,
#        -0.174386920980926, -0.187102633969119, -0.199818346957311,
#        -0.212534059945504, -0.225249772933696, -0.237965485921889,
