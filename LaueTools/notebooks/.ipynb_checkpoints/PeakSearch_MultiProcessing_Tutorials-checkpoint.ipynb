# %% [markdown]
# ***Laue Pattern peak search on a large set of binary Images using multiprocessing***
#
# on jupyter-slurm.esrf.fr
#
# or
#
# locally on desktop computer (with some cpus) and with access to the LaueTools environment or folder
#
# or lbm32gpu1  (@ESRF)

# %% [markdown]
# **This Notebook is a part of the LaueTools Package**
# Author: J.-S. Micha
#
# Last Revision:   January 2026
#
# tested with python 3.12  on jupyterlab and jupyter hub, jupyter-notebook
#
# **Objectives**
#
# - Load and display Laue pattern images
# - Perform a Peak Search, display found peaks
# - Perform a Peak Search on several images with several cpus

# %% [markdown]
# # SET runtime jupyterlab or not

# %%
JUPYTER_LAB = True # jupyter lab (at ESRF)
JUPYTER_HUB = False # jupyter hub or notebook
JUPYTER_VSCODE = False #  jupyter on vscode

# %% [markdown]
# # imports

# %% [markdown]
# **check number of available cores**

# %%
import multiprocessing
import itertools
nb_cpus = multiprocessing.cpu_count()
print(f"There are {nb_cpus} cores available - setting the variable nb_cpus to use them all ")
# Out:
# There are 64 cores available - setting the variable nb_cpus to use them all

# %%
if JUPYTER_HUB : # jupyterhub
    # %matplotlib notebook
elif JUPYTER_VSCODE: # vscode
    # %matplotlib widget
elif JUPYTER_LAB: #  jupyterlab
    # %matplotlib widget


import time,copy,os
from pathlib import Path
from tqdm import tqdm, tqdm_notebook

import multiprocessing
import itertools
from multiprocessing import active_children, cpu_count
nb_cpus = multiprocessing.cpu_count()
print(f"There are {nb_cpus} cores available - setting the variable nb_cpus to use them all ")

from ipywidgets import interact, interactive, fixed, interact_manual

# Third party modules
import matplotlib as mpl     # graphs and plots
import matplotlib.pyplot as plt
import numpy as np    # numerical arrays
import fabio
from matplotlib.patches import Ellipse
# matplotlib preferences
plt.style.use('classic')
mpl.rcParams['image.cmap'] = 'inferno'
mpl.rcParams['figure.facecolor'] = 'none'
mpl.rcParams['font.size'] = 8
# Out:
# There are 64 cores available - setting the variable nb_cpus to use them all

# %%
#OR use your own lauetools.
# Setting absolute path to LaueTools Modules if Lauetools has not been installed with pip
if 0: 
    import sys
    # for slurm machines
    # sys.path.insert(0,'/home/esrf/micha/lauetools_devNotebooks/lauetools')
    # # for lbm32gpu1 machine (test temp)
    #sys.path.insert(0,'/data/bm32/inhouse/STAFF/JSM/lauetools_devNotebooks/lauetools')

    sys.path.insert(0,'/data/bm32/inhouse/lauetoolsenv2/lib/python3.12/site-packages')
    
    import LaueTools as LT
    print('code from', LT.__file__)

# %%
# LaueTools modules
from LaueTools import IOLaueTools as IOLT   # read and write ASCII file  (IO) 
from LaueTools import readmccd as RMCCD       # read CCD and detector binary file, PeakSearch methods
from LaueTools import lauecore as LAUE       
from LaueTools import CrystalParameters as CP       
from LaueTools import generaltools as GT
from LaueTools import LaueGeometry as LaueGeo
from LaueTools import dict_LaueTools as DictLT
from LaueTools import imageprocessing as ImProc


import LaueTools as LT
print('Using lauetools code in ', LT.__file__)
# Out:
# loading lauetools_config.json in  /gpfs/jazzy/data/bm32/inhouse/SOFT/lauetoolsDEV/lauetools/LaueTools
# No user materials.yaml found. Using default materials.yaml
# loading lauetools_config.json in  /gpfs/jazzy/data/bm32/inhouse/SOFT/lauetoolsDEV/lauetools/LaueTools
# No user materials.yaml found. Using default materials.yaml
# -- WARNING: Missing library libtiff, Please install: pylibtiff if you need open some tiff images. However, Fabio or PIL can do the job!
# Using lauetools code in  None

# %% [markdown]
# # set user data filename & folders, detector type

# %%
expId = '322812'
expId = 'blc15488'
expId = 'utr20'
expId = 'ma6758'
expId='blc17163'

# %%
'/data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_map2D/scan0006/'
# Out:
# '/data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_map2D/scan0006/'

# %%
#/data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_Gealignwire/scan0003/CalibGe001_eiger4m_zcam100mm.de

# %%
if expId == 'blc17163':
    imageindex = 0 # Al
   
    maindatafolder = '/data/visitor/blc17163/bm32/20260609/RAW_DATA/'
    subfolderscandata = 'BaTiO3/BaTiO3_Map/scan0001/'
    
    imagefolder = Path(maindatafolder+'/'+subfolderscandata)
    
    # calibration parameters file
    #'/data/bm32/inhouse/data/laue/32-02-812/calibGe111_sCMOS_3202812_vendredi_ech44.det'
    detfile = Path('/data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_Gealignwire/scan0003/CalibGe001_eiger4m_zcam100mm.det')
    
    mainprocessed_data = Path(str(Path(maindatafolder).parent)+'//'+'PROCESSED_DATA')
    # Create the folder if it doesn't exist
    mainprocessed_data.mkdir(parents=True, exist_ok=True)
    datfilefolder = Path(str(mainprocessed_data)+'//'+subfolderscandata+'//'+'corfiles')
    corfilefolder = datfilefolder
     # Make sure directory exists
    os.makedirs(datfilefolder, exist_ok=True)

    prefixfilename= 'eiger4m_'
    suffix='.h5'
    CCDLabel = 'EIGER_4MCdTe'
    sizeofzeropadding = 4


if expId == 'ma6758':
    imageindex = 0 # Al
   
    maindatafolder = '/data/visitor/ma6758/bm32/20260312/RAW_DATA'
    subfolderscandata = '/Al/Al_map2D/scan0006'
    subfolderscandata = 'Al/Al_Al650um_daxm_h1.7_expo_5_nbsteps_650_hmicro1p7mm/scan0002'
    #subfolderscandata = 'ZrO2/ZrO2_ZrO2_1330C/scan0002'
    imagefolder = Path(maindatafolder+'/'+subfolderscandata)
    
    # calibration parameters file
    #'/data/bm32/inhouse/data/laue/32-02-812/calibGe111_sCMOS_3202812_vendredi_ech44.det'
    detfile = Path('/data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_Gealignwire/scan0003/CalibGe001_eiger4m_zcam100mm.det')
    
    mainprocessed_data = Path(str(Path(maindatafolder).parent)+'//'+'PROCESSED_DATA')
    # Create the folder if it doesn't exist
    mainprocessed_data.mkdir(parents=True, exist_ok=True)
    datfilefolder = Path(str(mainprocessed_data)+'//'+subfolderscandata+'//'+'corfiles')
    corfilefolder = datfilefolder
     # Make sure directory exists
    os.makedirs(datfilefolder, exist_ok=True)

    prefixfilename= 'eiger4m_'
    suffix='.h5'
    CCDLabel = 'EIGER_4MCdTe'
    sizeofzeropadding = 4

# utr 20 hercules al
if expId == 'utr20':
    imageindex = 0 # Al
   
    maindatafolder = '/data/visitor/utr20/bm32/20260310'
    subfolderscandata = '/RAW_DATA/Alafternoon/Alafternoon_map2D/scan0001'
    #subfolderscandata = 'ZrO2/ZrO2_ZrO2_1330C/scan0002'
    imagefolder = Path(maindatafolder+'/'+subfolderscandata)
    
    # calibration parameters file
    #'/data/bm32/inhouse/data/laue/32-02-812/calibGe111_sCMOS_3202812_vendredi_ech44.det'
    detfile = Path('/data/visitor/utr20/bm32/20260310/RAW_DATA/Alafternoon/Alafternoon_Ge/scan0001/calib_Ge_001_EIGER4M.det')
    
    mainprocessed_data = Path(maindatafolder+'//'+'PROCESSED_DATA')
    # Create the folder if it doesn't exist
    mainprocessed_data.mkdir(parents=True, exist_ok=True)
    datfilefolder = Path(str(mainprocessed_data)+'//'+subfolderscandata+'//'+'corfiles')
    corfilefolder = datfilefolder
     # Make sure directory exists
    os.makedirs(datfilefolder, exist_ok=True)

    prefixfilename= 'eiger4m_'
    suffix='.h5'
    CCDLabel = 'EIGER_4MCdTe'
    sizeofzeropadding = 4
    
    
if expId == '322812':
    imageindex = 0 # Al
    imageindex = 6 # Al2Cu
    
    maindatafolder = '/data/bm32/inhouse/data/laue/32-02-812'
    subfolderscandata = ''
    #subfolderscandata = 'ZrO2/ZrO2_ZrO2_1330C/scan0002'
    imagefolder = Path(maindatafolder+'/'+subfolderscandata)
    
    # calibration parameters file
    #'/data/bm32/inhouse/data/laue/32-02-812/calibGe111_sCMOS_3202812_vendredi_ech44.det'
    detfile = Path(maindatafolder+'/'+'calibGe111_sCMOS_3202812_vendredi_ech44.det')
    
    #mainprocessed_data = Path(maindatafolder+'//'+'PROCESSED_DATA')
    # Define the folder path starting from the home directory
    mainprocessed_data = Path("~/LaueTutorialsResults").expanduser()
    
    # Create the folder if it doesn't exist
    mainprocessed_data.mkdir(parents=True, exist_ok=True)
    
    datfilefolder = Path(str(mainprocessed_data)+'//'+subfolderscandata+'//'+'corfiles')
    corfilefolder = datfilefolder
    
    # Make sure directory exists
    os.makedirs(datfilefolder, exist_ok=True)
    
    #outputfolder = '/data/visitor/blc14894/bm32/20231007/NOBACKUP/'
    
    prefixfilename= 'ech28_'
    suffix='.tif'
    CCDLabel = 'sCMOS'
    sizeofzeropadding = 4
    print('images folder:  \n    =====> %s'%imagefolder)
    print('peaks list .dat files will be written in this folder: \n    =====> %s'%datfilefolder)
    print('peaks list .cor files will be written in this folder: \n    =====> %s'%corfilefolder)

    try:
        lltif = sorted(imagefolder.glob(f'{prefixfilename}*.tif'))
        imageindexmax = GT.getfileindex(lltif[-1])
        GT.printgreen(f'largest image index : {imageindexmax}. Set  `imageindexmax` to this value!')
    except:
        GT.printyellow(f'largest index of images file is not determined automatically... \n `imageindexmax` set to None')
    
    if Path(detfile).exists():
        GT.printgreen('calibration file exists!')
    else:
        GT.printyellow('calibration file or parameters are unknown yet! Cor files will not be created')
        
    rocessed_data.mkdir(parents=True, exist_ok=True)
    
    datfilefolder = Path(str(mainprocessed_data)+'//'+subfolderscandata+'//'+'corfiles')
    corfilefolder = datfilefolder
    
    # Make sure directory exists
    os.makedirs(datfilefolder, exist_ok=True)
    
    #outputfolder = '/data/visitor/blc14894/bm32/20231007/NOBACKUP/'
    
    prefixfilename= 'ech28_'
    suffix='.tif'
    CCDLabel = 'sCMOS'
    sizeofzeropadding = 4
print('images folder:  \n    =====> %s'%imagefolder)
print('peaks list .dat files will be written in this folder: \n    =====> %s'%datfilefolder)
print('peaks list .cor files will be written in this folder: \n    =====> %s'%corfilefolder)

try:
    lltif = sorted(imagefolder.glob(f'{prefixfilename}*.tif'))
    imageindexmax = GT.getfileindex(lltif[-1])
    GT.printgreen(f'largest image index : {imageindexmax}. Set  `imageindexmax` to this value!')
except:
    GT.printyellow(f'largest index of images file is not determined automatically... \n `imageindexmax` set to None')

if Path(detfile).exists():
    GT.printgreen('calibration file exists!')
else:
    GT.printyellow('calibration file or parameters are unknown yet! Cor files will not be created')
# Out:
# images folder:
#     =====> /data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_Al650um_daxm_h1.7_expo_5_nbsteps_650_hmicro1p7mm/scan0002
# peaks list .dat files will be written in this folder:
#     =====> /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/Al/Al_Al650um_daxm_h1.7_expo_5_nbsteps_650_hmicro1p7mm/scan0002/corfiles
# peaks list .cor files will be written in this folder:
#     =====> /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/Al/Al_Al650um_daxm_h1.7_expo_5_nbsteps_650_hmicro1p7mm/scan0002/corfiles
# largest index of images file is not determined automatically...
#  `imageindexmax` set to None
# calibration file exists!

# %%
detfile
# Out:
# PosixPath('/data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_Gealignwire/scan0003/CalibGe001_eiger4m_zcam100mm.det')

# %%
#32-02-812  Akamatsu et al  june 2018  Al/Al2Cu
if expId == '322812':
    imageindex = 0 # Al
    imageindex = 6 # Al2Cu
    
    maindatafolder = '/data/bm32/inhouse/data/laue/32-02-812'
    subfolderscandata = ''
    #subfolderscandata = 'ZrO2/ZrO2_ZrO2_1330C/scan0002'
    imagefolder = Path(maindatafolder+'/'+subfolderscandata)
    
    # calibration parameters file
    #'/data/bm32/inhouse/data/laue/32-02-812/calibGe111_sCMOS_3202812_vendredi_ech44.det'
    detfile = Path(maindatafolder+'/'+'calibGe111_sCMOS_3202812_vendredi_ech44.det')
    
    #mainprocessed_data = Path(maindatafolder+'//'+'PROCESSED_DATA')
    # Define the folder path starting from the home directory
    mainprocessed_data = Path("~/LaueTutorialsResults").expanduser()
    
    # Create the folder if it doesn't exist
    mainprocessed_data.mkdir(parents=True, exist_ok=True)
    
    datfilefolder = Path(str(mainprocessed_data)+'//'+subfolderscandata+'//'+'corfiles')
    corfilefolder = datfilefolder
    
    # Make sure directory exists
    os.makedirs(datfilefolder, exist_ok=True)
    
    #outputfolder = '/data/visitor/blc14894/bm32/20231007/NOBACKUP/'
    
    prefixfilename= 'ech28_'
    suffix='.tif'
    CCDLabel = 'sCMOS'
    sizeofzeropadding = 4


    
    print('images folder:  \n    =====> %s'%imagefolder)
    print('peaks list .dat files will be written in this folder: \n    =====> %s'%datfilefolder)
    print('peaks list .cor files will be written in this folder: \n    =====> %s'%corfilefolder)
    
    try:
        lltif = sorted(imagefolder.glob(f'{prefixfilename}*.tif'))
        imageindexmax = GT.getfileindex(lltif[-1])
        GT.printgreen(f'largest image index : {imageindexmax}. Set  `imageindexmax` to this value!')
    except:
        GT.printyellow(f'largest index of images file is not determined automatically... \n `imageindexmax` set to None')
    
    if Path(detfile).exists():
        GT.printgreen('calibration file exists!')
    else:
        GT.printyellow('calibration file or parameters are unknown yet! Cor files will not be created')

# %%
# Cr/Zr Ribart et al 
if expId == 'blc15488':

    maindatafolder = '/data/projects/mapgrainxl/blc15488/bm32/20240601/RAW_DATA'
    subfolderscandata = '/ech15/ech15_map2Dexpo0p1sec/scan0001'
    imagefolder = Path(maindatafolder+'/'+subfolderscandata)
    
    # calibration parameters file
    detfile = Path(maindatafolder+'//'+'ech15'+'//'+'ech15_Ge'+'//'+'scan0001/calibGe.det')

    
    #mainprocessed_data = Path(maindatafolder+'//'+'PROCESSED_DATA')
    # Define the folder path starting from the home directory
    mainprocessed_data = Path("~/LaueTutorialsResults").expanduser()
    mainprocessed_data = Path(mainprocessed_data / "peaksearch")
    
    # Create the folder if it doesn't exist
    mainprocessed_data.mkdir(parents=True, exist_ok=True)
    
    datfilefolder = Path(str(mainprocessed_data)+'//'+subfolderscandata+'//'+'corfiles')
    corfilefolder = datfilefolder
    
    # Make sure directory exists
    os.makedirs(datfilefolder, exist_ok=True)
    
    #outputfolder = '/data/visitor/blc14894/bm32/20231007/NOBACKUP/'
    
    prefixfilename= 'img_'
    suffix='.tif'
    CCDLabel = 'sCMOS'
    sizeofzeropadding = 4
    print('images folder:  \n    =====> %s'%imagefolder)
    print('peaks list .dat files will be written in this folder: \n    =====> %s'%datfilefolder)
    print('peaks list .cor files will be written in this folder: \n    =====> %s'%corfilefolder)

    try:
        lltif = sorted(imagefolder.glob(f'{prefixfilename}*.tif'))
        imageindexmax = GT.getfileindex(lltif[-1])
        GT.printgreen(f'largest image index : {imageindexmax}. Set  `imageindexmax` to this value!')
    except:
        GT.printyellow(f'largest index of images file is not determined automatically... \n `imageindexmax` set to None')
    
    if detfile is not None and Path(detfile).exists():
        GT.printgreen('calibration file exists!')
    else:
        GT.printyellow('calibration file or parameters are unknown yet! Cor files will not be created')

# %%
# crude & manuel way
if 0:
    imagefolder = '/home/micha/LaueProjects/Guinebretiere_Feb21/Diamond/'
    datfilefolder = '/home/micha/LaueProjects/Guinebretiere_Feb21/Diamond/datfiles'
    print('images folder:',imagefolder)
    prefixfilename= 'Gediam_'
    suffix='.tif'
    #sizeofzeropadding = 5    # image_00123.tif
    #sizeofzeropadding = 0    # image_123.tif
    sizeofzeropadding = 4
    
    print('images folder:',imagefolder)
    print('.dat files will be written in this folder: ', datfilefolder)

# %% [markdown]
# # [TEST] peaksearch workflow on 1 image:
#
# - read image
# - performe peaksearch
# - plot image(s) with peak found
# - write .dat file
# - write .cor file (given geometry calibration file .det)

# %% [markdown]
# **select 1 image file by `imageindex`**
# (splitting imagefilename allows loop over images:  prefix+index.extension)

# %%
imageindex=642

#----------------end of user input--------------------------------
paddedindex = '%s'%str(imageindex).zfill(sizeofzeropadding)
imagefilename = f"{prefixfilename}{paddedindex}{suffix}"

if not Path(imagefolder).exists():
    GT.printred('"imagefolder" does not exists!')
    
elif not (Path(imagefolder)/imagefilename).exists():
    GT.printyellow(f'this image does not exist. Check imageindex and/or imagefolder: {imagefilename} , {imagefolder}')
else:
    GT.printgreen(f"imagefilename : {imagefilename}")
# Out:
# imagefilename : eiger4m_0642.h5

# %% [markdown]
# **read image file and get data**

# %%
print("imagefilename :",imagefilename)
im = fabio.open(Path(imagefolder)/imagefilename)
fig, ax = plt.subplots(ncols=2, figsize=(10,4))
ax[0].clear() # for lbm32gpu1
ax[1].clear()  # for lbm32gpu1
ax[0].imshow(np.log10(np.clip(im.data,a_min=0.000001, a_max=999999999999999)),vmin=0.1,vmax=2,cmap=plt.cm.OrRd)  # cmap=plt.cm.inferno)
ax[0].set_title('log scale')
ax[1].imshow(im.data,vmin=0,vmax=1000,cmap=plt.cm.OrRd)
ax[1].set_title('linear scale')
fig.suptitle(f'{imagefolder} \n {imagefilename}')
plt.show()
# Out:
# imagefilename : eiger4m_0642.h5
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## PEAKSEARCH
#
# ***peaksearch*** performed on modified image 'newdataimage' (by default this is done on image given as first argument). Peaksearch results can purged from peaks already present in file as an optional argument Remove_BlackListedPeaks_fromfile.

# %%
def maskpixel_in_bands(XYcam, verbose=False):
    """shift if needed pts if falling in band gaps
    XYcam is a list of 2D pts (shape = n1,2)
    return an array of 2D pts of the same shape
    """
    if verbose: print("Initial points:", XYcam)

    XYcam = np.array(XYcam)

    # Forbidden y bands
    y_bands = [(512, 549), (1062, 1099), (1612, 1649)]
    # Forbidden x bands
    x_bands = [(513, 514), (1028, 1039), (1553, 1554)]

    # Create masks for y and x bands
    y_mask = np.zeros(len(XYcam), dtype=bool)
    for band in y_bands:
        y_mask |= (XYcam[:, 1] >= band[0]) & (XYcam[:, 1] <= band[1])

    x_mask = np.zeros(len(XYcam), dtype=bool)
    for band in x_bands:
        x_mask |= (XYcam[:, 0] >= band[0]) & (XYcam[:, 0] <= band[1])

    # Count modifications
    y_modified = np.sum(y_mask)
    x_modified = np.sum(x_mask)

    # Modify y for points in forbidden y bands
    XYcam[y_mask, 1] -= 40
    # Modify x for points in forbidden x bands
    XYcam[x_mask, 0] -= 20
    
    if verbose:
        print('(y_modified, x_modified)')
        print((y_modified, x_modified))

        print("Modified points:", XYcam)

    # Return modified list
    return XYcam

# %%
def removepixel_in_bands(XYcam, verbose=False):
    """
    """
    if verbose: print("Initial points:", XYcam)

    XYcam = np.array(XYcam)

    n = 11
    # Forbidden y bands
    y_bands = [[512, 549], [1062, 1099], [1612, 1649]] + np.array([[-n,+n],[-n,+n],[-n,+n]])
    # Forbidden x bands
    x_bands = [[513, 514], [1028, 1039], [1553, 1554]] + np.array([[-n,+n],[-n,+n],[-n,+n]])

    # Create masks for y and x bands
    y_mask = np.zeros(len(XYcam), dtype=bool)
    for band in y_bands:
        y_mask |= (XYcam[:, 1] >= band[0]) & (XYcam[:, 1] <= band[1])

    x_mask = np.zeros(len(XYcam), dtype=bool)
    for band in x_bands:
        x_mask |= (XYcam[:, 0] >= band[0]) & (XYcam[:, 0] <= band[1])

    inbands = np.logical_or(y_mask, x_mask)
    print('inbands',inbands.shape)

    # Count modifications
    y_modified = np.sum(y_mask)
    x_modified = np.sum(x_mask)

    inbandsindex = np.where(inbands)
        # Return modified list
    return inbandsindex

# %%
imageindex = 642

Data_for_localMaxima = 'auto_background'
IntensityThreshold = 1500
boxsize = 8
maxPixelDistanceRejection = 5
PeakSizeRange=(0.3, 10)

# --------- end of user input  ------------

paddedindex = '%s'%str(imageindex).zfill(sizeofzeropadding)
imagefilename = f"{prefixfilename}{paddedindex}{suffix}"
fullpathimagefile = Path(imagefolder)/imagefilename
print(fullpathimagefile)
#imagefilename = composite_image_filename
#imagefilename =filtered_image_filename

ti1= time.time()

#blacklistedpeaksfile=os.path.join(folder,'Blacklist.dat')
# TODO to implement in input argument Remove_BlackListedPeaks_fromfile
#blacklistedpeaksfile = None

res=RMCCD.PeakSearch(filename=os.path.join(imagefolder,imagefilename),
                     IntensityThreshold=IntensityThreshold,
                     boxsize=boxsize,
                     CCDLabel=CCDLabel,
                     fit_peaks_gaussian=1,
                    return_histo=0,
                    local_maxima_search_method=0,
                     Data_for_localMaxima=Data_for_localMaxima,
                     Saturation_value=80000,
                     maxPixelDistanceRejection=maxPixelDistanceRejection,
                    NumberMaxofFits=5000,
                     PeakSizeRange=PeakSizeRange,
                     formulaexpression='A-1.1*B',
                     Remove_BlackListedPeaks_fromfile=None,
                     # end of most important parameters
                    xtol=0.001,
                    FitPixelDev=10,
                    center=None,
                    boxsizeROI=(200, 200),
                    PixelNearRadius=3,
                    removeedge=2,
                    thresholdConvolve=200,
                    paramsHat=(4, 5, 2),
                    verbose=0,
                    position_definition=1,
                    peakposition_definition='max',
                    write_execution_time=1,
                    Saturation_value_flatpeak=65535,
                    MinIntensity=0,
                    Fit_with_Data_for_localMaxima=False,
                    reject_negative_baseline=True,
                    listrois=None,
                     npixels=10
                    )
tps =time.time()
print(f"peak search time {np.round(tps-ti1,2)} seconds")
nbpeaks = len(res[0])
print(f"{nbpeaks} peaks  are found!")
# Out:
# /data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_Al650um_daxm_h1.7_expo_5_nbsteps_650_hmicro1p7mm/scan0002/eiger4m_0642.h5
# Initial points: [[ 512  483]
#  [1026  492]
#  [1550  175]
#  ...
#  [1326 2161]
#  [1399 2161]
#  [1919 2161]]
# peak search time 2.99 seconds
# 1973 peaks  are found!

# %% [markdown]
# ## PLOT peaks positions in pixel units
# unpack results as laue spots properties

# %%
peaklist=res[0]
print(peaklist.shape)

# indexremove = removepixel_in_bands(peaklist[:,:2])
# print(len(indexremove[0]))

# peaklist = np.delete(peaklist,indexremove[0], axis=0)

print("nb of peaks in image",len(peaklist))
#peaklist[:,:2]
peak_X = peaklist[:,0]
peak_Y = peaklist[:,1]
peak_Isub = peaklist[:,2]
peak_fwaxmaj = peaklist[:,3]
peak_fwaxmin = peaklist[:,4]
peak_inclination = peaklist[:,5]
Xdev = peaklist[:,6]
Ydev = peaklist[:,7]
peak_bkg = peaklist[:,8]
Ipixmax = peaklist[:,9]
peak_Itot = peak_Isub + peak_bkg


print(peaklist.shape)
# Out:
# (2056, 10)
# nb of peaks in image 2056
# (2056, 10)

# %% [markdown]
# ***plot the results   with zoom on the 100 first most intense peaks***

# %%
fig0, ax0 = plt.subplots()

ax0.imshow(im.data,interpolation='nearest',vmin=1000,vmax=1200,cmap=plt.cm.inferno)
ax0.scatter(peak_X-1,peak_Y-1,marker='+',color='lightgreen',s=30)
ax0.set_xlim((0,2000))
ax0.set_ylim((2000,0))

fig0.suptitle('Laue pattern %s\n%d peaks'%(fullpathimagefile,len(peaklist)))

npeaks = len(peak_X)
sqrt_nvignette = min(10,int(np.ceil(np.sqrt(npeaks))))
fig = plt.figure(figsize=(sqrt_nvignette,sqrt_nvignette), )
fig.suptitle('First most intense Laue spots')
for iii in np.arange(min(npeaks,100)):
    try:
        ax = fig.add_subplot(sqrt_nvignette,sqrt_nvignette,iii+1)
        x,y = peak_X[iii]-1,peak_Y[iii]-1
        size = max(np.abs(peak_fwaxmaj[iii]),np.abs(peak_fwaxmin[iii]),3)
        intensity = peak_Itot[iii]
        xmin,xmax = int(np.round(x-1.5*size)),int(np.round(x+1.5*size))+1
        ymin,ymax = int(np.round(y-1.5*size)),int(np.round(y+1.5*size))+1
        ax.pcolormesh(np.arange(xmin-.5,xmax+.5), np.arange(ymin-.5, ymax+.5), 
                      im.data[ymin:ymax,xmin:xmax], 
                      vmin=0,vmax=intensity,cmap=plt.cm.jet)#plt.cm.inferno)
        ax.scatter(x,y,marker='+',color='lightgreen',s=30,label='fitted') # fitted
        e = Ellipse(xy=(x,y),
            width=peak_fwaxmaj[iii],
            height=peak_fwaxmin[iii],
            angle=peak_inclination[iii]+90)
        ax.add_artist(e)
        e.set_edgecolor('green')
        e.set_facecolor('none')
        ax.set_xlim(xmin,xmax-1)
        ax.set_ylim(ymax-1,ymin)
        ax.set_xticks([])
        ax.set_yticks([]) 
        #if iii == min(npeaks,100)-1:
    except Exception as e:
        print(e)
        pass
    #    plt.legend()

fig.tight_layout()
plt.show()
# Out:
# Dimensions of C (15, 16) should be one smaller than X(17) and Y(17) while using shading='flat' see help(pcolormesh)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
imageindex = 642

imageindexmax = 650 #51*51-1

fullpath = os.path.join(imagefolder,f'{prefixfilename}%04d{suffix}'%imageindex)
#  --------- end of user input  ------------

with fabio.open(fullpath) as img:
    imgdata = img.data
#rint('imgdata.shape', imgdata.shape, '\n\n')
    
fig1,ax1 = plt.subplots()
#fig.suptitle('%s\n%s'%(ExperimentFolder,fullpath.rsplit('/RAW_DATA/')[1]))
# #ax.imshow(np.log10(imgdata), vmin = 3, vmax = 3.5, cmap=plt.cm.inferno)
ax1.imshow(imgdata, vmin = 1000, vmax =6000, cmap=plt.cm.OrRd)
# for pt in roiposition:
#     ax.scatter(pt[0],pt[1],marker='+',color='r')
    
def plotimage(imageindex=imageindex,vmin=0, vmax=1000, show_rois=False):
    # TO IMPROVE  see wrokflow JSM   laueimproc
    #print('showroi', show_rois)
    ymin, ymax = ax1.get_ylim()
    xmin, xmax = ax1.get_xlim()
    ax1.clear()
    ax1.set_xlim(xmin, xmax)
    ax1.set_ylim(ymin, ymax)
    ymin, ymax, xmin, xmax = int(ymin),int(ymax),int(xmin),int(xmax)
    if ymin>ymax:
        yminc = ymin
        ymin = ymax
        ymax = yminc
    fullpath = os.path.join(imagefolder,f'{prefixfilename}%04d{suffix}'%imageindex)
    with fabio.open(fullpath) as img:
        imgdata = img.data
        #print('imgdata.shape', imgdata.shape, '\n\n')
    if 'RAW_DATA' in fullpath:
        figtitle = '%s\n%s'%(maindatafolder,fullpath.rsplit('/RAW_DATA/')[1])
    else:
        figtitle = fullpath
    ax1.imshow(imgdata, vmin = vmin, vmax =vmax, cmap=plt.cm.jet, interpolation='nearest')
    
    if show_rois:
        #print('show rois!')
        for ptx,pty in zip(peak_X,peak_Y):
            ax1.scatter(ptx,pty,marker='+',color='r')
    ax1.set_title(figtitle)  
    plt.show()

#imageindexmax = 30000 # len(d['listindices'])-1
# imageindexmax = 4000
interactive(plotimage, imageindex=(0,imageindexmax),
            vmin=(0,1010),vmax=(1015,20000), show_rois=[False, True])
# Out:
# interactive(children=(IntSlider(value=642, description='imageindex', max=650), IntSlider(value=0, description=…

# %% [markdown]
# if you feel you can get more peaks from the image, you may decide to reduce `IntensityThreshold` in the `PeakSearch` function above

# %%
MASK_REGION = False # True for SCMOS SCMOS_9M with some regions with weird pixels, False for sCMOS, sCMOS_4M = IMSTAR_bin#

def deletepeaks(peaklist, boxparams):
    """delete rows of peaklist array where first 2 components satisfy the box condition
    |X-Xcenter|<halfwidth & |Y-Ycenter|<halfheight 
    
    where Xcenter, Ycenter, halfwidth, halfheight = boxparams
    
    return a modified copy of peaklist"""
    
    Xcenter, Ycenter, halfwidth, halfheight = boxparams
    X,Y = peaklist[:,:2].T
    ## some peaks removal according to X, Y
    condX = np.fabs(X-Xcenter)<halfwidth
    condY = np.fabs(Y-Ycenter)<halfheight
    cond = np.logical_and(condX, condY)
    filteredpeaklist =  np.delete(peaklist, np.where(cond)[0], axis=0)
    return filteredpeaklist

#Xcenter, Ycenter, halfwidth, halfheight 
boxparams = 1009,1000,7,1100
if MASK_REGION:
    peaklist = deletepeaks(peaklist, boxparams)

# %% [markdown]
# ## write peak list in .dat file

# %%
# to add a string in the output file name
AddedString = ''

outputpeaklistprefix = prefixfilename+AddedString+str(imageindex).zfill(sizeofzeropadding)

print('peaklist.shape  (nb spots, nb properties)       :\n',peaklist.shape)
print("fullpathimagefile      :\n =====>",fullpathimagefile)
print('outputpeaklistprefix   :\n =====>', outputpeaklistprefix)

fullpath_datfile= RMCCD.writepeaklist(peaklist,outputpeaklistprefix,
                                      outputfolder=datfilefolder,
                                      initialfilename=fullpathimagefile)
datfilename = fullpath_datfile
print('Peaklist in datfilename     :\n =====>',datfilename)
# Out:
# peaklist.shape  (nb spots, nb properties)       :
#  (342, 10)
# fullpathimagefile      :
#  =====> /data/visitor/ma6758/bm32/20260312/RAW_DATA/Al/Al_map2D/scan0006/eiger4m_4939.h5
# outputpeaklistprefix   :
#  =====> eiger4m_4939
# Peaklist in datfilename     :
#  =====> /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_4939.dat

# %% [markdown]
# ## read calibration .det file and write .cor file
#
# - set `dictcalibparams`
# - .cor file (containing Laue spots porperties : X, Y, I  + 2$\theta$, $\chi$ scttering angles)

# %%
dictcalibparams = None
try:
    dictcalibparams = None
    #dictcalibparams = IOLT.readCalib_det_file('/data/bm32/inhouse/LAUE/Test02Sep20_LAUE/Jeudi/calibSilukas.det')
    dictcalibparams = IOLT.readCalib_det_file(detfile)
except NameError:
    GT.printred('please provide the path to a .det file')

# write . cor if calibration parameters are known
if dictcalibparams is not None:# 
    if isinstance(dictcalibparams, dict):

        datfolder, datfile = os.path.split(fullpath_datfile)

        corfile =LaueGeo.convert2corfile(datfile,
                    [],  # should be useless and pixelsize argument is also missing...
                    dirname_in=datfolder,
                    dirname_out=datfolder,
                    CCDCalibdict=dictcalibparams,
                    add_props=True)
        print('corfile', corfile)
# Out:
# corfile /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_4939.cor

# %%
dictcalibparams
# Out:
# {'dd': 100.0,
#  'xcen': 1079.36,
#  'ycen': 982.75,
#  'xbet': 0.189,
#  'xgam': 0.288,
#  'pixelsize': 0.075,
#  'xpixelsize': 0.075,
#  'ypixelsize': 0.075,
#  'CCDLabel': 'EIGER_4MCdTe',
#  'framedim': array([2162., 2068.]),
#  'detectordiameter': 162.15,
#  'kf_direction': 'Z>0',
#  'UB_calib': array([ 0.6231077,  0.7813704, -0.0345984,  0.004684 , -0.047963 ,
#         -0.9988381, -0.782122 ,  0.6222217, -0.0335461]),
#  'CCDCalibParameters': [100.0, 1079.36, 982.75, 0.189, 0.288]}

# %% [markdown]
# #  PEAK SEARCH MULTIPROCESSING

# %% [markdown]
# PEAK SEARCH MULTIPROCESSING
#
# - all peaks properties may also be stored in `allresults` object
# - .dat and .cor files results may be written in several folders
# - masks may be applied

# %% [markdown]
# ## SET elementary peaksearch function with user defined parameters

# %%
#-------------------USER INPUT------------------------------------------
# global variables
addedstring = '' # 'nb_'  # string added to all .dat filename
#CCDLabel = 'sCMOS'
#suffix = '.tif'
if expId == '322812':
    formulaexpression = 'A-1.1*B'
    IntensityThreshold = 250
    boxsize = 10
    maxPixelDistanceRejection = 15
    PeakSizeRange=(0.1, 10)
if expId == 'blc15488':
    formulaexpression = 'A-1.1*B'
    IntensityThreshold = 250
    boxsize = 10
    maxPixelDistanceRejection = 15
    PeakSizeRange=(0.1, 10)

if expId == 'utr20':
    formulaexpression = 'A-1.1*B'
    IntensityThreshold = 100
    boxsize = 8
    maxPixelDistanceRejection = 10
    PeakSizeRange=(0.1, 10)

if expId == 'ma6758':
    formulaexpression = 'A-1.1*B'
    IntensityThreshold = 100
    boxsize = 8
    maxPixelDistanceRejection = 10
    PeakSizeRange=(0.15, 5)

#----  get rid of painful hot or bad pixels
MASK_REGION = True
#Xcenter, Ycenter, halfwidth, halfheight 
boxparams = 1009,1000,7,1100

#----------------------------------------------------------------------------
# atomic function : peaksearch on a single image
# fine parameters of RMCCD.PeakSearch can be modified here
def peaksearch_oneimage(imageindex, prefix=prefixfilename,
                               imagefolder=imagefolder,
                                outputfolder=datfilefolder,
                                sizeofzeropadding=sizeofzeropadding,
                                IntensityThreshold=IntensityThreshold,boxsize=boxsize,
                               dictcalibparams =None,
                               verbose=0):
    """
    peaksearch on single image including auto background removal, fit local intensity array without background
    
    imageindex:   int, index of image in image filename (last digits before .extension)
    prefix: str, prefix of image filename. Should end with '_'
    imagefolder: str, absolute path to image files
    outputfolder: str, absolute path to peaks list files (.dat and .cor)
    sizeofzeropadding: maximal number of digits for zero padding (usually 4)
    IntensityThreshold: int, minimum local peak amplitude"""
    
    
    
    paddedindex = '%s'%str(imageindex).zfill(sizeofzeropadding)
    imagefilename = f"{prefixfilename}{paddedindex}{suffix}"
    
    pathfile=os.path.join(imagefolder,imagefilename)
    
    
    res=RMCCD.PeakSearch(filename=pathfile,
                     IntensityThreshold=IntensityThreshold,
                     boxsize=boxsize,
                     CCDLabel=CCDLabel,
                     fit_peaks_gaussian=1,
                    return_histo=0,
                    local_maxima_search_method=0,
                     Data_for_localMaxima=Data_for_localMaxima,
                     Saturation_value=80000,
                     maxPixelDistanceRejection=maxPixelDistanceRejection,
                    NumberMaxofFits=5000,
                     PeakSizeRange=PeakSizeRange,
                     formulaexpression='A-1.1*B',
                     Remove_BlackListedPeaks_fromfile=None,
                     # end of most important parameters
                    xtol=0.001,
                    FitPixelDev=10,
                    center=None,
                    boxsizeROI=(200, 200),
                    PixelNearRadius=3,
                    removeedge=2,
                    thresholdConvolve=200,
                    paramsHat=(4, 5, 2),
                    verbose=verbose-1,
                    position_definition=1,
                    peakposition_definition='max',
                    write_execution_time=1,
                    Saturation_value_flatpeak=65535,
                    MinIntensity=0,
                    Fit_with_Data_for_localMaxima=False,
                    reject_negative_baseline=True,
                    listrois=None
                    )
    
    if res is None:
        return [imageindex,0]+[]
    peaklist=res[0]
    if peaklist is not None:
        nbpeaks = len(peaklist)
        
    if peaklist is not None and MASK_REGION:
        #peaklist = deletepeaks(peaklist, boxparams)
        indexremove = removepixel_in_bands(peaklist[:,:2])
        #print('MASK_REGION: nb peaks removed',len(indexremove[0]))
        
        peaklist = np.delete(peaklist,indexremove[0], axis=0)

        nbpeaks = len(peaklist)

    outputpeaklistprefix = f"{prefixfilename}{addedstring}{paddedindex}"
    fullpathimagefile = os.path.join(imagefolder,imagefilename)

    fullpath_datfile= RMCCD.writepeaklist(peaklist,outputpeaklistprefix,outputfolder=outputfolder,
                                    initialfilename=fullpathimagefile, verbose=verbose-1)
    if fullpath_datfile is None:
        return [imageindex,0]+[]
    
    if verbose>0:  print('fullpath_datfile',fullpath_datfile)
#     print('len(peaklist)',len(peaklist))
    if dictcalibparams is not None:# write also .cor file
        if isinstance(dictcalibparams, dict):

            datfolder, datfile = os.path.split(fullpath_datfile)

            finalcorfilename = LaueGeo.convert2corfile(datfile,
                        [],  # should be useless and pixelsize argument is also missing...
                        dirname_in=datfolder,
                        dirname_out=datfolder,
                        CCDCalibdict=dictcalibparams,
                        add_props=True,
                        verbose=verbose-1)
            
            if verbose>0:  print('finalcorfilename',finalcorfilename)
            
    return [imageindex, nbpeaks]+peaklist.tolist()

# %%
# [TEST] just to check some peak search
#dictcalibparams = None
if 1:
    for kk in range(100,103):
        res = peaksearch_oneimage(kk, prefix=prefixfilename, imagefolder=imagefolder, outputfolder=datfilefolder,
                                      sizeofzeropadding=sizeofzeropadding,
                                       IntensityThreshold=IntensityThreshold,
                                      boxsize=boxsize,
                                     dictcalibparams=dictcalibparams, verbose=0)
        print(f'kk = {kk}, found %d peaks'%res[1])
    GT.printgreen('Test completed')
# Out:
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# Initial points: [[1027    3]
#  [ 497    7]
#  [1025   13]
#  ...
#  [1025 1779]
#  [ 512 1858]
#  [1044 1865]]
# inbands (60,)
# In convert2corfile():
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0100.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# kk = 100, found 60 peaks
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# Initial points: [[ 496    5]
#  [1026    7]
#  [1025   13]
#  ...
#  [1041 1760]
#  [1025 1827]
#  [1044 1865]]
# inbands (63,)
# In convert2corfile():
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0101.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# kk = 101, found 60 peaks
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# Initial points: [[1549    1]
#  [ 497    7]
#  [1460   95]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]]
# inbands (56,)
# In convert2corfile():
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0102.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# kk = 102, found 54 peaks
# Test completed

# %%
datfilefolder, dictcalibparams
# Out:
# (PosixPath('/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles'),
#  {'dd': 100.0,
#   'xcen': 1079.36,
#   'ycen': 982.75,
#   'xbet': 0.189,
#   'xgam': 0.288,
#   'pixelsize': 0.075,
#   'xpixelsize': 0.075,
#   'ypixelsize': 0.075,
#   'CCDLabel': 'EIGER_4MCdTe',
#   'framedim': array([2162., 2068.]),
#   'detectordiameter': 162.15,
#   'kf_direction': 'Z>0',
#   'UB_calib': array([ 0.6231077,  0.7813704, -0.0345984,  0.004684 , -0.047963 ,
#          -0.9988381, -0.782122 ,  0.6222217, -0.0335461]),
#   'CCDCalibParameters': [100.0, 1079.36, 982.75, 0.189, 0.288]})

# %%
# uncomment to ignore warnings in the following
#import warnings
#warnings.filterwarnings('ignore')

# %% [markdown]
# ## PEAKSEARCH on all images

# %%
imageindexmax=10000

# %%
#-------------------USER INPUT----------------------------------------------
# image index coverage
firstimageindex = 0
lastimageindex = 46*601-1

IntensityThreshold = 100 #1000 #200
outputfolder = datfilefolder
BUILD_ALLRESULTS_LIST = True

# it is advisable to have folder with a limited nb of files (chunk size = 5000)
SPLITINTOSUBFOLDER = False
nbfiles_per_folder = 5000
subfolderprefix = 'datfiles_'

nbcpus= 120 # > 1 !!

verboselevel = 0

#--------------end of USER INPUT-----------------------------------------------
if lastimageindex is None:
    GT.printred('lastimageindex is None ie undefined. Please set to an indexinteger ')
listindices = np.arange(firstimageindex,lastimageindex+1,1).tolist()

#if __name__=='__main__':
    
if SPLITINTOSUBFOLDER:
    ll = np.array(listindices)
    # create subfolders
    nbfolders = np.amax(ll//nbfiles_per_folder)+1
    for k in range(nbfolders):
        try:
            os.mkdir(os.path.join(outputfolder,subfolderprefix+'%d_%d'%(k*nbfiles_per_folder,
                                                             (k+1)*nbfiles_per_folder-1)))
        except FileExistsError:
            continue

    # ugly way to prepare the list of outputfolder
    outputfolders = []
    for _idx in ll:
        subfolder_idx = _idx // nbfiles_per_folder 
        path_to_subfolder = os.path.join(outputfolder,
                                         subfolderprefix+'%d_%d'%(subfolder_idx*nbfiles_per_folder,
                                                             (subfolder_idx+1)*nbfiles_per_folder-1))
        outputfolders.append(path_to_subfolder)
else:
    outputfolders = itertools.repeat(outputfolder)

#---------------------Multiprocessing-----------------------------------------------
maxnbcpus = cpu_count()
if nbcpus is None:
    nbcpus = maxnbcpus
else:
    nbcpus = max(2,min(nbcpus,maxnbcpus))
#print('nbcpus', nbcpus)

nbimages = len(listindices)
#----------------------------------

t00 = time.time()
print(f'using peaksearch  on {nbimages} images, with {nbcpus} cpu(s)')

args_peaksearch = zip(listindices,
               itertools.repeat(prefixfilename),
               itertools.repeat(imagefolder),
               outputfolders,
              itertools.repeat(sizeofzeropadding),
                itertools.repeat(IntensityThreshold),
                      itertools.repeat(boxsize),
                      itertools.repeat(dictcalibparams),
                      itertools.repeat(verboselevel)
               )

with multiprocessing.Pool(nbcpus) as pool:
    if BUILD_ALLRESULTS_LIST:
        allresults = pool.starmap(peaksearch_oneimage, tqdm(args_peaksearch, total=len(listindices),
                              desc='peak search progress bar:'), chunksize=1)
    else:
        pool.starmap(peaksearch_oneimage, tqdm(args_peaksearch, total=len(listindices),
                              desc='peak search progress bar:'), chunksize=1)

elapsedtime=time.time()-t00
children = active_children()
print(f'total time is {elapsedtime:.3f} sec for {nbimages} images and {nbcpus} cpu(s)')
print(f'Active children: {len(children)}')

if len(children)==0:
    GT.printgreen('\n*****************\nPeak Search is completed !!\n*****************')

if BUILD_ALLRESULTS_LIST:
    GT.printgreen('"allresults" is built and contained all peaks properties...')

print('Build files (.dat and .cor) are in\n =======>%s'%outputfolders)
# Out:
# using peaksearch  on 27646 images, with 64 cpu(s)
# peak search progress bar::   0%|          | 0/27646 [00:00<?, ?it/s]
# CCDLabel: CCDLabel:  CCDLabel:  CCDLabel: CCDLabel: CCDLabel: EIGER_4MCdTeCCDLabel:  CCDLabel:
#   EIGER_4MCdTe EIGER_4MCdTe
# EIGER_4MCdTeEIGER_4MCdTeEIGER_4MCdTeCCDLabel:
# nb of pixels
# nb of pixels
# EIGER_4MCdTeCCDLabel: CCDLabel:  CCDLabel: nb of pixelsCCDLabel: nb of pixels
#
# EIGER_4MCdTe(2162, 2068)  nb of pixelsnb of pixels (2162, 2068) CCDLabel:
#
# nb of pixelsEIGER_4MCdTe EIGER_4MCdTe(2162, 2068) EIGER_4MCdTe CCDLabel:
# (2162, 2068)nb of pixelsCCDLabel:
# EIGER_4MCdTe
# CCDLabel: EIGER_4MCdTe
#
# (2162, 2068)(2162, 2068)
#   nb of pixels
#
#  EIGER_4MCdTenb of pixels
# CCDLabel: (2162, 2068)nb of pixels
#  nb of pixels (2162, 2068)EIGER_4MCdTe  CCDLabel:
# nb of pixels  EIGER_4MCdTe
#
# (2162, 2068)EIGER_4MCdTe
#   (2162, 2068)(2162, 2068)nb of pixels(2162, 2068)
#
# nb of pixels
# EIGER_4MCdTeCCDLabel: (2162, 2068) CCDLabel:
# CCDLabel:
# nb of pixels
# nb of pixels
#  (2162, 2068)  CCDLabel:
#   EIGER_4MCdTe(2162, 2068)(2162, 2068)CCDLabel: EIGER_4MCdTe (2162, 2068)
# CCDLabel: EIGER_4MCdTe
#
#
#
# EIGER_4MCdTe nb of pixels
# nb of pixels nb of pixels
#
# CCDLabel: CCDLabel:  EIGER_4MCdTe  EIGER_4MCdTenb of pixels(2162, 2068)(2162, 2068)(2162, 2068)nb of pixels
#   EIGER_4MCdTe
#
#
#
#
# (2162, 2068)EIGER_4MCdTenb of pixelsnb of pixels(2162, 2068)CCDLabel: CCDLabel: (2162, 2068)
# CCDLabel: EIGER_4MCdTenb of pixelsCCDLabel:
#  CCDLabel: nb of pixels
#
# (2162, 2068)   nb of pixels
# CCDLabel: CCDLabel: (2162, 2068)(2162, 2068)EIGER_4MCdTe EIGER_4MCdTe
#
#
# EIGER_4MCdTeEIGER_4MCdTe(2162, 2068)
#
#   CCDLabel: EIGER_4MCdTenb of pixels
# CCDLabel: CCDLabel: EIGER_4MCdTe
# nb of pixels
#
# CCDLabel: EIGER_4MCdTenb of pixels(2162, 2068)
#    nb of pixels nb of pixels
#
# nb of pixelsEIGER_4MCdTe(2162, 2068)CCDLabel: EIGER_4MCdTe EIGER_4MCdTe(2162, 2068) nb of pixels
# CCDLabel:
#
#
# EIGER_4MCdTe
# (2162, 2068)nb of pixelsCCDLabel: nb of pixels(2162, 2068) (2162, 2068)nb of pixels(2162, 2068)
#
#  EIGER_4MCdTe
#
#
# nb of pixels(2162, 2068)(2162, 2068)EIGER_4MCdTe
#  CCDLabel: (2162, 2068)nb of pixels EIGER_4MCdTe
#
#
#
# CCDLabel: (2162, 2068) CCDLabel:  nb of pixels
# nb of pixels
# (2162, 2068)EIGER_4MCdTeCCDLabel:
#
# (2162, 2068)CCDLabel: CCDLabel: EIGER_4MCdTeEIGER_4MCdTe
# CCDLabel: nb of pixels(2162, 2068)
# CCDLabel:
# EIGER_4MCdTe
# nb of pixels  CCDLabel: CCDLabel:    EIGER_4MCdTe(2162, 2068)EIGER_4MCdTenb of pixels(2162, 2068)EIGER_4MCdTe
#
#
#  CCDLabel: nb of pixelsCCDLabel: CCDLabel:
#
# EIGER_4MCdTe
# (2162, 2068) EIGER_4MCdTeCCDLabel: CCDLabel:  nb of pixelsCCDLabel:  nb of pixelsCCDLabel:
# nb of pixels
#
# EIGER_4MCdTe(2162, 2068) CCDLabel:    nb of pixelsEIGER_4MCdTeEIGER_4MCdTe
# nb of pixelsCCDLabel:  CCDLabel:  EIGER_4MCdTe
#  (2162, 2068)
# (2162, 2068) (2162, 2068)CCDLabel:
# EIGER_4MCdTeEIGER_4MCdTe  CCDLabel: EIGER_4MCdTe
# nb of pixelsnb of pixels
#
# (2162, 2068)
# EIGER_4MCdTenb of pixels
# EIGER_4MCdTe
#
#  (2162, 2068)nb of pixels   EIGER_4MCdTeEIGER_4MCdTe
#
#
# nb of pixelsnb of pixels
# nb of pixels (2162, 2068)(2162, 2068)
#
# EIGER_4MCdTeEIGER_4MCdTenb of pixels
# (2162, 2068) nb of pixels
#
#
# (2162, 2068)nb of pixels
#  nb of pixelsnb of pixels(2162, 2068)nb of pixels(2162, 2068)(2162, 2068)
# (2162, 2068)
#  (2162, 2068)
#
# (2162, 2068)
# (2162, 2068)(2162, 2068)(2162, 2068)
# CCDLabel:
#
#
#
#  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# Initial points: [[ 497    7]
#  [1559   21]
#  [1460   95]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1397 1911]]Initial points:
# Initial points:Initial points:  [[1026    0]
#  [1027    3]
#  [ 497    7]
#  ...
#  [1040 1800]
#  [1041 1824]
#  [1044 1865]] [[ 496    5]
#  [ 497    7]
#  [ 570   96]
#  ...
#  [1024 1779]
#  [1040 1780]
#  [1044 1865]][[1027    3]
#  [ 497    7]
#  [1027   13]
#  ...
#  [1027 1819]
#  [1044 1865]
#  [1950 1935]]
#
#
# Initial points: Initial points:[[ 497    7]
#  [1026    9]
#  [1025   14]
#  ...
#  [1044 1865]
#  [1397 1911]
#  [1950 1935]]
#  Initial points:Initial points:[[1026    3]
#  [ 497    7]
#  [1555    6]
#  ...
#  [1025 1771]
#  [1024 1785]
#  [1044 1865]]Initial points:   [[ 496    5]
#  [1555    6]
#  [ 497    7]
#  ...
#  [1044 1792]
#  [ 512 1858]
#  [1044 1865]]
# [[ 497    7]
#  [1027    7]
#  [1026    9]
#  ...
#  [1025 1740]
#  [ 512 1756]
#  [1044 1865]]
#
# [[ 496    5]
#  [ 497    7]
#  [1025   12]
#  ...
#  [1043 1748]
#  [ 512 1858]
#  [1044 1865]]Initial points:Initial points:
#   [[ 497    7]
#  [1027    9]
#  [1025   12]
#  ...
#  [1043 1770]
#  [ 512 1858]
#  [1044 1865]][[1025    3]
#  [ 497    7]
#  [1024    5]
#  ...
#  [1027 1754]
#  [ 924 1759]
#  [1044 1865]]
# Initial points: Initial points:
# [[1025    3]
#  [ 496    5]
#  [1025    7]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [ 676 1948]] Initial points:
#  [[ 497    7]
#  [1555   24]
#  [1460   95]
#  ...
#  [1040 1752]
#  [ 512 1858]
#  [1044 1865]]
# [[ 497    7]
#  [1025   12]
#  [1024   15]
#  ...
#  [ 926 1767]
#  [1042 1788]
#  [1044 1865]]Initial points:
#  Initial points:Initial points:Initial points:  [[1025    1]
#  [ 496    5]
#  [1025   20]
#  ...
#  [1024 1758]
#  [1043 1766]
#  [1044 1865]]Initial points:[[1024    1]
#  [1552    3]
#  [ 497    7]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]][[ 496    5]
#  [ 497    7]
#  [1024   21]
#  ...
#  [1044 1865]
#  [1950 1935]
#  [1546 2066]]
#
#
# Initial points:[[ 496    5]
#  [1027    7]
#  [1027   13]
#  ...
#  [1041 1787]
#  [1042 1818]
#  [1044 1865]]Initial points:
#  [[1024    1]
#  [ 497    7]
#  [1024    9]
#  ...
#  [1025 1823]
#  [1044 1865]
#  [1950 1935]] Initial points:
# Initial points:[[1025    0]
#  [ 497    7]
#  [1026   16]
#  ...
#  [1040 1813]
#  [1044 1865]
#  [1044 1870]]Initial points:[[ 496    6]
#  [1026   20]
#  [ 951   51]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [ 818 2068]]   Initial points:Initial points:Initial points:[[ 497    7]
#  [1460   95]
#  [ 570   96]
#  ...
#  [1041 1784]
#  [1027 1791]
#  [1044 1865]]
# [[ 497    7]
#  [1026   18]
#  [1555   19]
#  ...
#  [1041 1805]
#  [1027 1806]
#  [1044 1865]] Initial points:Initial points:[[ 497    7]
#  [1025    5]
#  [1025   11]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1397 1911]][[1025    2]
#  [ 496    5]
#  [1460   95]
#  ...
#  [ 917 1759]
#  [1042 1777]
#  [1044 1865]]Initial points:
#     [[ 497    7]
#  [1024   21]
#  [1555   24]
#  ...
#  [1044 1749]
#  [1024 1756]
#  [1044 1865]]
#
#
# [[1024    1]
#  [ 497    7]
#  [1026   12]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]][[ 497    7]
#  [1552   15]
#  [1024   18]
#  ...
#  [1024 1772]
#  [1041 1797]
#  [1044 1865]][[ 497    7]
#  [1026    7]
#  [1552   15]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]]Initial points:Initial points:
# Initial points:Initial points:[[ 497    7]
#  [1025   24]
#  [ 570   96]
#  ...
#  [1026 1788]
#  [1042 1794]
#  [1044 1865]]Initial points:Initial points:
# Initial points:
#
#
#
#      Initial points:[[ 497    7]
#  [1027    8]
#  [1555   10]
#  ...
#  [1042 1781]
#  [1027 1822]
#  [1044 1865]]Initial points:Initial points:[[ 496    5]
#  [1026    6]
#  [1555    6]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]]Initial points: [[ 496    5]
#  [ 497    7]
#  [1026    8]
#  ...
#  [1025 1779]
#  [ 512 1858]
#  [1044 1865]][[1026    3]
#  [ 497    7]
#  [1026   23]
#  ...
#  [1027 1788]
#  [1024 1805]
#  [1044 1865]][[ 496    5]
#  [ 497    7]
#  [1026    8]
#  ...
#  [1025 1795]
#  [ 512 1858]
#  [1044 1865]][[ 496    5]
#  [1024    7]
#  [1042   81]
#  ...
#  [1044 1865]
#  [1044 1880]
#  [1159 1887]][[1026    1]
#  [ 496    5]
#  [1026    6]
#  ...
#  [1044 1821]
#  [1044 1865]
#  [1950 1935]]
#
#
#
#
#
#  Initial points:Initial points:[[ 497    7]
#  [1027    9]
#  [1460   95]
#  ...
#  [1041 1853]
#  [ 512 1858]
#  [1044 1865]]
# Initial points:Initial points:Initial points:Initial points:Initial points:Initial points:[[ 496    5]
#  [1025   20]
#  [1460   95]
#  ...
#  [1042 1757]
#  [1041 1768]
#  [1044 1865]]Initial points:   Initial points:Initial points:Initial points:Initial points: [[ 496    5]
#  [1024   21]
#  [1026   22]
#  ...
#  [1044 1808]
#  [ 512 1858]
#  [1044 1865]]
#
#  Initial points:
# [[ 497    7]
#  [1026    9]
#  [1555   10]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1397 1911]][[1026    3]
#  [1339    4]
#  [ 497    7]
#  ...
#  [1044 1865]
#  [1044 1870]
#  [1040 1966]] [[1025    2]
#  [ 496    5]
#  [ 497    7]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1397 1911]]Initial points:Initial points:
# [[ 497    7]
#  [1550   10]
#  [1026   14]
#  ...
#  [1043 1753]
#  [ 512 1858]
#  [1044 1865]][[ 496    5]
#  [1027    5]
#  [1555    6]
#  ...
#  [1043 1803]
#  [ 512 1858]
#  [1044 1865]][[ 497    7]
#  [1025    7]
#  [1460   95]
#  ...
#  [1555 1812]
#  [1044 1865]
#  [1397 1911]][[1027    1]
#  [ 496    5]
#  [ 497    7]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1044 1870]][[ 496    5]
#  [ 512    5]
#  [1027    5]
#  ...
#  [1044 1784]
#  [1026 1794]
#  [1044 1865]] [[ 497    7]
#  [1026   10]
#  [1026   12]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1397 1911]]
# [[1027    3]
#  [ 496    5]
#  [1024   22]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]]
#  [[ 497    7]
#  [1555    6]
#  [1549   20]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1397 1911]]
#
# [[ 497    7]
#  [ 512   22]
#  [1550   24]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]]
#
# [[1026    3]
#  [ 496    5]
#  [ 497    7]
#  ...
#  [1025 1782]
#  [1025 1796]
#  [1044 1865]]
# [[ 496    5]
#  [1460   95]
#  [ 570   96]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]]
# [[ 497    7]
#  [1025   20]
#  [1025   24]
#  ...
#  [1558 1855]
#  [1044 1865]
#  [1950 1935]]
#
#
#
# Initial points:Initial points:Initial points:
# Initial points: [[ 497    7]
#  [1026   10]
#  [1027   22]
#  ...
#  [ 918 1758]
#  [1043 1776]
#  [1044 1865]]
#
#   [[ 496    5]
#  [1555    8]
#  [1027    9]
#  ...
#  [1027 1745]
#  [1044 1769]
#  [1044 1865]][[ 496    5]
#  [ 497    7]
#  [1025    9]
#  ...
#  [1024 1803]
#  [ 512 1858]
#  [1044 1865]]
#
# [[ 497    7]
#  [ 517    7]
#  [1027    7]
#  ...
#  [1044 1774]
#  [1042 1783]
#  [1044 1865]]
# [[ 496    5]
#  [1550    7]
#  [1555    9]
#  ...
#  [1040 1816]
#  [1044 1865]
#  [1950 1935]]
# Initial points: [[1024    1]
#  [ 497    7]
#  [1024   18]
#  ...
#  [1026 1773]
#  [1044 1786]
#  [1044 1865]]
# [[1027    3]
#  [ 497    7]
#  [1024   21]
#  ...
#  [ 919 1765]
#  [ 512 1858]
#  [1044 1865]]
# Initial points: [[ 517    0]
#  [ 497    7]
#  [1555    6]
#  ...
#  [1044 1865]
#  [1397 1911]
#  [1950 1935]]
# inbands (63,)
# In convert2corfile():
# In convert2corfile()  at the end:
# inbandsWriting .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0059.cor
# (54,)in folder
#  inbands/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# In convert2corfile():
#  (58,)
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0017.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# In convert2corfile():
# inbandsIn convert2corfile()  at the end: inbands
#  Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0005.cor (64,)
# in folder(57,)
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# In convert2corfile(): In convert2corfile():
#
# inbandsIn convert2corfile()  at the end: In convert2corfile()  at the end:
#
# (60,)
# Writing .cor file in Writing .cor file in   /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0018.corCCDLabel: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0032.cor
#
# EIGER_4MCdTein folderin folder
#   In convert2corfile(): nb of pixels/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles inbands
# (2162, 2068)
# peak search progress bar::   0%|          | 129/27646 [00:02<09:31, 48.13it/s]
#  (60,)
# In convert2corfile():
# In convert2corfile()  at the end: inbandsCCDLabel: In convert2corfile()  at the end:
#
# Initial points:(58,)Writing .cor file in Writing .cor file in EIGER_4MCdTe
#
# nb of pixels /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0048.cor /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0000.corCCDLabel: (2162, 2068)
#
#
# [[ 497    7]
#  [1551    9]
#  [1024   10]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1158 1890]]in folderin folder
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# EIGER_4MCdTe
#
# inbandsnb of pixelsIn convert2corfile():
# (2162, 2068)
# (60,)
# In convert2corfile()  at the end:
# Writing .cor file in  In convert2corfile(): /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0029.cor
#
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   0%|          | 134/27646 [00:02<10:30, 43.63it/s]
# In convert2corfile()  at the end: inbands
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0053.cor
# in folder  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(56,)
#
# In convert2corfile():
# inbandsIn convert2corfile()  at the end:
#  Writing .cor file in (64,)
# inbands/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0033.cor
#  in folder(60,) In convert2corfile():
# CCDLabel:
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesEIGER_4MCdTe
#
# nb of pixelsIn convert2corfile()  at the end:
# Writing .cor file in (2162, 2068)
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0025.cor
# In convert2corfile(): in folder
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# inbands In convert2corfile()  at the end:
# (62,)Writing .cor file in
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0037.cor
# In convert2corfile(): in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   0%|          | 137/27646 [00:03<13:19, 34.42it/s]
# inbands (59,)
# inbandsIn convert2corfile()  at the end:
# (57,)Writing .cor file in In convert2corfile():
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0007.corIn convert2corfile():
#
# in folder In convert2corfile()  at the end:
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesWriting .cor file in inbandsCCDLabel:
# In convert2corfile()  at the end:
#  Writing .cor file in  (62,)EIGER_4MCdTe /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0034.cor
# CCDLabel:
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0036.cornb of pixelsCCDLabel:
#
# in folder in folder(2162, 2068)    /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# EIGER_4MCdTeEIGER_4MCdTe
# CCDLabel:
#
#
# EIGER_4MCdTe
# nb of pixels CCDLabel: (2162, 2068)In convert2corfile(): nb of pixelsnb of pixels
#
#   (2162, 2068)EIGER_4MCdTe(2162, 2068)
#
#
# CCDLabel: nb of pixels (2162, 2068)
# inbands (59,)
#  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# In convert2corfile()  at the end: CCDLabel:
#  Writing .cor file in inbands EIGER_4MCdTe
# nb of pixels/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0002.cor
#  inbandsin folder(57,)(2162, 2068)
#
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(66,)
# In convert2corfile(): In convert2corfile():
# peak search progress bar::   1%|          | 141/27646 [00:03<16:10, 28.33it/s]
# In convert2corfile():
# In convert2corfile()  at the end: In convert2corfile()  at the end:
#
# Writing .cor file in  Writing .cor file in /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0004.corIn convert2corfile()  at the end:
#
# in folderWriting .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0012.cor
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0060.corin folder
# in folder  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# inbandsinbands inbands(67,)
#   (58,)inbands(52,)
#
# In convert2corfile():
#  (58,)
# In convert2corfile(): In convert2corfile():
#
# In convert2corfile()  at the end:
# inbandsWriting .cor file in In convert2corfile():
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0015.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   1%|          | 145/27646 [00:04<17:44, 25.83it/s]
# In convert2corfile()  at the end: CCDLabel: (58,)In convert2corfile()  at the end:
#
#
#  EIGER_4MCdTeIn convert2corfile()  at the end: Writing .cor file in Writing .cor file in
#
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0063.corWriting .cor file in nb of pixels/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0024.cor
# (2162, 2068)
#  in folder/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0022.cor
# in folder
#  in folder In convert2corfile(): /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0014.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   1%|          | 149/27646 [00:04<17:38, 25.98it/s]
# inbands (59,)
# In convert2corfile():
# inbandsinbandsinbandsinbandsCCDLabel:    (68,)EIGER_4MCdTe
# (61,)
# nb of pixels  In convert2corfile()  at the end: inbandsinbands(67,)
#  Initial points: (61,)(58,)
#
#
# (2162, 2068)
# [[ 496    5]
#  [1025    6]
#  [1460   95]
#  ...
#  [1043 1828]
#  [ 512 1858]
#  [1044 1865]]
#  Writing .cor file in (65,)
# In convert2corfile():
#
# In convert2corfile(): CCDLabel:  In convert2corfile():
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0038.corIn convert2corfile()  at the end:
# Writing .cor file in   In convert2corfile():
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0046.cor
#
# in folderEIGER_4MCdTe /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# in folder
#  In convert2corfile(): nb of pixelsIn convert2corfile():  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# (2162, 2068)
# CCDLabel:
#
# In convert2corfile()  at the end: CCDLabel:
#  EIGER_4MCdTeWriting .cor file in
# nb of pixels  In convert2corfile()  at the end: (2162, 2068)/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0006.cor
#
#
# in folderWriting .cor file in In convert2corfile()  at the end:
# In convert2corfile()  at the end: Writing .cor file in /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0035.cor EIGER_4MCdTe
# CCDLabel: CCDLabel: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0039.cor
# in folder
#
# Writing .cor file in
#  nb of pixels/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesin folder
#   (2162, 2068)EIGER_4MCdTe/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# CCDLabel:
# peak search progress bar::   1%|          | 153/27646 [00:04<19:51, 23.07it/s]
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0044.cornb of pixels CCDLabel:  EIGER_4MCdTeinbands(2162, 2068)CCDLabel: In convert2corfile()  at the end: EIGER_4MCdTe
#
#
#
# in foldernb of pixels
# EIGER_4MCdTenb of pixels
#
#   nb of pixelsWriting .cor file in /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles EIGER_4MCdTe
# (2162, 2068) CCDLabel:
# nb of pixels(63,)(2162, 2068)
# (2162, 2068)
#
#
#  (2162, 2068)EIGER_4MCdTe/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0056.cor
#
#
# nb of pixelsin folder  inbands/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(2162, 2068)
#
# In convert2corfile():
#  (62,)
# CCDLabel: In convert2corfile():
# EIGER_4MCdTeIn convert2corfile()  at the end:
#
# Writing .cor file in CCDLabel:  nb of pixels (2162, 2068)/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0013.cor
# CCDLabel: In convert2corfile()  at the end:  EIGER_4MCdTeinbandsinbands
#
#
#  CCDLabel: in foldernb of pixelsWriting .cor file in  (2162, 2068)   EIGER_4MCdTe /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(69,)
#
# (63,)inbands/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0023.cor
# CCDLabel:
# peak search progress bar::   1%|          | 157/27646 [00:04<21:19, 21.48it/s]
#
# EIGER_4MCdTe
# (66,)
#  in folder
#
# nb of pixelsEIGER_4MCdTeIn convert2corfile():
# nb of pixels  nb of pixelsIn convert2corfile():
# (2162, 2068)
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(2162, 2068)In convert2corfile():
#
#
#
# (2162, 2068)In convert2corfile()  at the end:
# Writing .cor file in  In convert2corfile()  at the end: In convert2corfile()  at the end:
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0043.cor
#
#
# Writing .cor file in inbands CCDLabel: Writing .cor file in in folder/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0031.cor  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0019.cor/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
#
#  (58,)in folderin folderCCDLabel:
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#   EIGER_4MCdTe/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# EIGER_4MCdTe
# nb of pixelsinbands
# peak search progress bar::   1%|          | 161/27646 [00:05<20:03, 22.84it/s]
#
# (2162, 2068)In convert2corfile():
# nb of pixels
# (2162, 2068)
# In convert2corfile()  at the end:
# Writing .cor file in  (64,)
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0009.corin folderIn convert2corfile():  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# inbandsinbands (60,)
# In convert2corfile()  at the end:
# Writing .cor file in In convert2corfile():  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0049.cor
#
# (64,)in folder
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesCCDLabel:
#  In convert2corfile(): CCDLabel: In convert2corfile()  at the end: CCDLabel: EIGER_4MCdTe
#
# EIGER_4MCdTe
#
# nb of pixels  nb of pixels Writing .cor file in EIGER_4MCdTe /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0003.cor(2162, 2068)
# (2162, 2068)
#
# nb of pixels
#  in folder(2162, 2068)
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# In convert2corfile()  at the end:
# CCDLabel:  EIGER_4MCdTe
# nb of pixelsCCDLabel: Writing .cor file in  (2162, 2068)inbands
# CCDLabel: EIGER_4MCdTe
# nb of pixels  (2162, 2068)
# CCDLabel:  EIGER_4MCdTe
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0042.cor  nb of pixels
#  EIGER_4MCdTe(2162, 2068)
# nb of pixels
# in folder  (54,)/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# (2162, 2068)
# peak search progress bar::   1%|          | 165/27646 [00:05<26:58, 16.98it/s]
# CCDLabel:  EIGER_4MCdTeinbands
# In convert2corfile(): nb of pixels
#  (2162, 2068)
# In convert2corfile()  at the end:
# (58,)Writing .cor file in
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0050.cor
# In convert2corfile(): in folder
#  inbandsinbands/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# In convert2corfile()  at the end:   (55,)(62,)
#
# Writing .cor file in
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0011.cor
# in folderIn convert2corfile():
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesIn convert2corfile():
#
# In convert2corfile()  at the end:
# Writing .cor file in In convert2corfile()  at the end: CCDLabel:
#  Writing .cor file in EIGER_4MCdTe
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0026.cor/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0028.cornb of pixels
#
#  (2162, 2068)in folderin folder
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   1%|          | 169/27646 [00:05<29:22, 15.59it/s]
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# inbands (55,)
# In convert2corfile():
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0010.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# CCDLabel: inbandsCCDLabel: CCDLabel: inbands EIGER_4MCdTe
# nb of pixelsEIGER_4MCdTe
# (63,)nb of pixelsEIGER_4MCdTe(2162, 2068)
#
# (2162, 2068)
#
# nb of pixels (2162, 2068)
# In convert2corfile():
# (64,)
# inbandsIn convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0021.cor
# in folder inbands  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(59,)(58,)CCDLabel:
#
#
# In convert2corfile():
#  In convert2corfile(): In convert2corfile():
#
# inbandsEIGER_4MCdTeIn convert2corfile()  at the end:
# (52,)
#
# Writing .cor file in nb of pixels  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0051.cor(2162, 2068)
# in folderCCDLabel: In convert2corfile():  In convert2corfile()  at the end:
#
# Writing .cor file in
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesinbandsinbands  In convert2corfile()  at the end:
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0058.corEIGER_4MCdTe
# (61,)
# In convert2corfile()  at the end:  in folder
# Writing .cor file in Writing .cor file in
#   (61,)nb of pixels/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0027.cor/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# in folder/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0062.corinbands
# peak search progress bar::   1%|          | 173/27646 [00:06<34:59, 13.09it/s]
#
#  in folderIn convert2corfile(): In convert2corfile(): (2162, 2068)(57,)
#
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# inbands
#  In convert2corfile()  at the end:
# Writing .cor file in In convert2corfile()  at the end:
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0069.cor
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(60,)in folder
# Writing .cor file in
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesIn convert2corfile():  In convert2corfile(): /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0061.cor
#
#
#
# CCDLabel: In convert2corfile()  at the end:
# Writing .cor file in  EIGER_4MCdTe/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0047.corin folderIn convert2corfile()  at the end:
#
# in foldernb of pixels
#  Writing .cor file in (2162, 2068)
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0020.corinbands/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# in folder
# peak search progress bar::   1%|          | 177/27646 [00:06<30:06, 15.20it/s]
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(54,)/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
#
# In convert2corfile(): CCDLabel: CCDLabel:
# EIGER_4MCdTe
# nb of pixels (2162, 2068)
# inbandsEIGER_4MCdTe (61,)CCDLabel:
# In convert2corfile()  at the end:
#
# nb of pixels  (2162, 2068)In convert2corfile():
# Writing .cor file in EIGER_4MCdTe
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0045.cor
#
# nb of pixelsCCDLabel: in folder  EIGER_4MCdTe inbands
# inbands/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(2162, 2068) (55,)nb of pixels
#
# In convert2corfile():
#  (2162, 2068)
# (60,)In convert2corfile()  at the end:
#
#
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0055.corWriting .cor file in inbands
# In convert2corfile(): in folder
#   /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(64,)
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0008.cor
# peak search progress bar::   1%|          | 181/27646 [00:06<27:22, 16.72it/s]
# in folderIn convert2corfile():
#  In convert2corfile()  at the end: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# inbands
# Writing .cor file in  CCDLabel: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0041.corIn convert2corfile()  at the end:
#
# Writing .cor file in   /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0052.cor
# in folderinbandsin folder  EIGER_4MCdTe /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(61,)
# (62,)
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesnb of pixels
#
#  CCDLabel: In convert2corfile(): (2162, 2068)
#
# In convert2corfile(): EIGER_4MCdTeCCDLabel: CCDLabel:  In convert2corfile()  at the end:
#
#
# EIGER_4MCdTe
# (2162, 2068)
# Writing .cor file in nb of pixels  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0057.corin folder
#  EIGER_4MCdTenb of pixels/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesIn convert2corfile()  at the end: inbands
# peak search progress bar::   1%|          | 185/27646 [00:06<23:00, 19.89it/s]
#
#
# nb of pixels (2162, 2068)(57,)CCDLabel:
# (2162, 2068)
# Writing .cor file in
#  EIGER_4MCdTe
#  CCDLabel: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0001.cor nb of pixelsEIGER_4MCdTe
#
# nb of pixelsin folder(2162, 2068)
# Initial points:(2162, 2068)
# In convert2corfile():   CCDLabel:
# CCDLabel: [[ 496    5]
#  [1024   22]
#  [1460   95]
#  ...
#  [1044 1865]
#  [1040 1882]
#  [1950 1935]]
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesEIGER_4MCdTeEIGER_4MCdTeCCDLabel:
#
#  EIGER_4MCdTe
# In convert2corfile()  at the end:
# nb of pixelsnb of pixelsnb of pixels   (2162, 2068)
# (2162, 2068)(2162, 2068)
#
#
# CCDLabel:  EIGER_4MCdTeWriting .cor file in nb of pixels
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0040.cor
# (2162, 2068)in folder
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# CCDLabel:  EIGER_4MCdTeinbands
# nb of pixelsinbands  (2162, 2068) (53,)
#
# (60,)
# In convert2corfile():
# In convert2corfile():
# In convert2corfile()  at the end:
# Writing .cor file in inbands In convert2corfile()  at the end: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0030.cor
#
# in folder(60,)Initial points:Writing .cor file in    /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles[[1027    3]
#  [ 497    7]
#  [1555    6]
#  ...
#  [1025 1796]
#  [ 512 1858]
#  [1044 1865]]
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0054.cor
#
# in folderIn convert2corfile():
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   1%|          | 189/27646 [00:07<27:39, 16.55it/s]
# In convert2corfile()  at the end: CCDLabel:
# Writing .cor file in  EIGER_4MCdTe
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0016.cor
# in foldernb of pixels  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles(2162, 2068)
#
# CCDLabel:  EIGER_4MCdTeInitial points:
# nb of pixels[[ 496    5]
#  [ 497    7]
#  [ 499    9]
#  ...
#  [1026 1790]
#  [1040 1846]
#  [1044 1865]] (2162, 2068)
#
# CCDLabel:  EIGER_4MCdTe
# inbandsnb of pixels  (2162, 2068)
# (67,)CCDLabel:
#  In convert2corfile(): EIGER_4MCdTe
#
# nb of pixelsIn convert2corfile()  at the end:
# (2162, 2068)Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0067.cor
#
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# Initial points: Initial points:[[1025    4]
#  [ 496    5]
#  [1027    5]
#  ...
#  [1042 1780]
#  [ 512 1858]
#  [1044 1865]]
# Initial points:[[ 497    7]
#  [1026   11]
#  [1027   18]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]] [[ 496    5]
#  [1027    5]
#  [1024   20]
#  ...
#  [1042 1781]
#  [1044 1787]
#  [1044 1865]]
#
# Initial points: [[ 496    5]
#  [1460   95]
#  [ 570   96]
#  ...
#  [1040 1824]
#  [ 512 1858]
#  [1044 1865]]
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# Initial points: [[1024    0]
#  [ 497    7]
#  [1555    9]
#  ...
#  [1042 1803]
#  [1044 1847]
#  [1044 1865]]
# Initial points: [[ 497    7]
#  [1027   11]
#  [1550   14]
#  ...
#  [1024 1812]
#  [ 512 1858]
#  [1044 1865]]
# Initial points: [[1026    3]
#  [ 497    7]
#  [1555    6]
#  ...
#  [1043 1825]
#  [ 512 1858]
#  [1044 1865]]
# Initial points: [[ 497    7]
#  [1555   16]
#  [1026   22]
#  ...
#  [1040 1765]
#  [1025 1804]
#  [1044 1865]]
# Initial points: [[ 497    7]
#  [1025    7]
#  [1555   23]
#  ...
#  [1025 1791]
#  [1044 1865]
#  [ 248 1918]]
# Initial points: [[1024    4]
#  [ 496    5]
#  [ 497    7]
#  ...
#  [1042 1776]
#  [ 512 1858]
#  [1044 1865]]
# Initial points: [[1026    4]
#  [ 496    5]
#  [1555   15]
#  ...
#  [1044 1809]
#  [1044 1865]
#  [1044 1870]]
# Initial points: [[ 497    7]
#  [1024   14]
#  [1024   19]
#  ...
#  [1024 1766]
#  [1025 1796]
#  [1044 1865]]
# Initial points: [[ 496    6]
#  [1555   18]
#  [ 570   96]
#  ...
#  [1026 1812]
#  [ 512 1858]
#  [1044 1865]]
# inbands (61,)
# Initial points: [[ 497    7]
#  [1024    5]
#  [1027   18]
#  ...
#  [1025 1775]
#  [1044 1776]
#  [1044 1865]]In convert2corfile():
#
# inbandsIn convert2corfile()  at the end:  (59,)
#
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0075.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# In convert2corfile():
# inbands (54,)
# In convert2corfile():
# In convert2corfile()  at the end: In convert2corfile()  at the end:
# Writing .cor file in
# Writing .cor file in   /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0088.cor/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0099.cor
# in folder
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesInitial points:
# peak search progress bar::   1%|          | 193/27646 [00:08<1:08:19,  6.70it/s]
#  [[ 496    5]
#  [1027    9]
#  [1024   13]
#  ...
#  [1026 1803]
#  [1044 1833]
#  [1044 1865]]
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# CCDLabel: Initial points: EIGER_4MCdTe
#  nb of pixels[[1024    1]
#  [1024    3]
#  [ 497    7]
#  ...
#  [1024 1793]
#  [1024 1801]
#  [1044 1865]]
# (2162, 2068)
# inbands (65,)
# inbandsIn convert2corfile():
#  (59,)
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0084.corIn convert2corfile():
#
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesinbands
#  (58,)
# In convert2corfile()  at the end: inbands(56,)
#
# Writing .cor file in  In convert2corfile(): /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0076.cor
#
# in folderIn convert2corfile():
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesIn convert2corfile()  at the end:
#
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0071.cor
# Writing .cor file in in folder  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   1%|          | 197/27646 [00:08<58:55,  7.76it/s]
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0093.cor
# in folder Initial points:/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles CCDLabel: [[ 496    5]
#  [1027    6]
#  [1555    7]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]]
#
#  CCDLabel: EIGER_4MCdTe EIGER_4MCdTeInitial points:
#
# nb of pixelsnb of pixels[[1026    4]
#  [ 497    7]
#  [1026    7]
#  ...
#  [1555 1781]
#  [1027 1788]
#  [1044 1865]]
#  (2162, 2068)Initial points:
# (2162, 2068)
# [[ 497    7]
#  [1024    9]
#  [1555   16]
#  ...
#  [1024 1790]
#  [ 512 1858]
#  [1044 1865]]
# Initial points: [[ 497    7]
#  [1025   19]
#  [1024   21]
#  ...
#  [ 917 1761]
#  [1025 1784]
#  [1044 1865]]
# inbands Initial points:(60,) [[ 496    5]
#  [ 497    7]
#  [1025    7]
#  ...
#  [1025 1834]
#  [ 512 1858]
#  [1044 1865]]
#
# In convert2corfile(): inbands
# Initial points:  [[1550    2]
#  [1024    4]
#  [ 497    7]
#  ...
#  [1044 1800]
#  [ 512 1858]
#  [1044 1865]]CCDLabel: (66,)
# In convert2corfile()  at the end:
#  Initial points:CCDLabel: EIGER_4MCdTe CCDLabel:
#
# [[1024    1]
#  [ 497    7]
#  [1026    6]
#  ...
#  [1044 1865]
#  [1397 1911]
#  [1950 1935]]CCDLabel: Writing .cor file in  nb of pixelsIn convert2corfile(): EIGER_4MCdTe
# EIGER_4MCdTe
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0087.cor (2162, 2068)
# EIGER_4MCdTe
#
# nb of pixels
# in folder nb of pixels
# nb of pixels  (2162, 2068)/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# (2162, 2068)
# (2162, 2068)In convert2corfile()  at the end:
#
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0080.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# Initial points: [[ 497    7]
#  [1027    5]
#  [1026    9]
#  ...
#  [1044 1776]
#  [ 512 1858]
#  [1044 1865]]
# Initial points:Initial points:Initial points: CCDLabel:  EIGER_4MCdTe[[ 497    7]
#  [1555    6]
#  [1024   15]
#  ...
#  [1044 1865]
#  [1397 1911]
#  [1950 1935]]
# inbands
# nb of pixels[[1024    0]
#  [ 512    1]
#  [1027    3]
#  ...
#  [1025 1796]
#  [ 512 1858]
#  [1044 1865]] [[ 496    5]
#  [1026    7]
#  [1025   13]
#  ...
#  [1041 1760]
#  [1025 1827]
#  [1044 1865]]
#  inbands
# (2162, 2068)(65,)
#
#  (53,)
# In convert2corfile(): CCDLabel:
# In convert2corfile():
# In convert2corfile()  at the end: EIGER_4MCdTe
# Initial points:
# nb of pixelsWriting .cor file in In convert2corfile()  at the end:
#   (2162, 2068)Writing .cor file in [[ 497    7]
#  [1551    9]
#  [1555   14]
#  ...
#  [1026 1782]
#  [ 512 1858]
#  [1044 1865]]
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0094.cor
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0097.cor
# in folderin folder  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   1%|          | 201/27646 [00:09<1:06:20,  6.90it/s]
# Initial points: Initial points: [[ 496    5]
#  [ 497    7]
#  [1555    6]
#  ...
#  [1042 1813]
#  [1044 1865]
#  [1041 1903]][[ 496    5]
#  [1024   16]
#  [1026   17]
#  ...
#  [1025 1787]
#  [1043 1819]
#  [1044 1865]]
# inbands
#  (65,)
# In convert2corfile():
# In convert2corfile()  at the end: inbands
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0114.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#  CCDLabel: (52,)
# EIGER_4MCdTe
# nb of pixelsInitial points: (2162, 2068)In convert2corfile():
# [[ 497    6]
#  [1026    8]
#  [1027   22]
#  ...
#  [1027 1762]
#  [1041 1773]
#  [1044 1865]]
#
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# inbandsIn convert2corfile()  at the end:  (60,)
#
# Writing .cor file in  In convert2corfile(): /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0119.cor
#
# in folder inbandsIn convert2corfile()  at the end: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# Writing .cor file in
# peak search progress bar::   1%|          | 205/27646 [00:10<1:06:07,  6.92it/s]
# (55,)
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0074.cor
# in folderIn convert2corfile():
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0103.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# Initial points:CCDLabel:  EIGER_4MCdTe
# nb of pixels[[ 496    5]
#  [ 497    7]
#  [1026   12]
#  ...
#  [1040 1855]
#  [ 512 1858]
#  [1044 1865]]
# (2162, 2068)Initial points:
#  [[ 496    5]
#  [1024    5]
#  [ 497    7]
#  ...
#  [1042 1784]
#  [1043 1823]
#  [1044 1865]]
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)inbands
# inbandsinbands CCDLabel: (58,) Initial points:EIGER_4MCdTe
#
# nb of pixels   (2162, 2068)[[ 497    7]
#  [1027   10]
#  [1025   12]
#  ...
#  [1042 1851]
#  [1044 1865]
#  [1950 1935]](60,)(55,)
#
# Initial points:
#
#  [[1549    1]
#  [ 497    7]
#  [1460   95]
#  ...
#  [ 512 1858]
#  [1044 1865]
#  [1950 1935]]
# In convert2corfile(): inbands
# In convert2corfile()  at the end: In convert2corfile():
# Writing .cor file in In convert2corfile():  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0098.cor
#
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
#  (57,)
# In convert2corfile():
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0107.corinbands
# in folder/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# (59,)
# CCDLabel: In convert2corfile():
# In convert2corfile()  at the end:
#  EIGER_4MCdTeIn convert2corfile()  at the end: Writing .cor file in
#
#  Writing .cor file in nb of pixels /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0123.corIn convert2corfile()  at the end:  inbands/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0079.cor(2162, 2068)
#
#
#
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesWriting .cor file in
# peak search progress bar::   1%|          | 209/27646 [00:10<1:03:34,  7.19it/s]
# in folderin folder(58,)
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0113.cor/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
#  In convert2corfile():
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# CCDLabel: inbands EIGER_4MCdTe
# nb of pixels
#  (2162, 2068)In convert2corfile()  at the end: Initial points:  CCDLabel:
# (65,) Initial points:[[ 497    7]
#  [1027    8]
#  [1024    9]
#  ...
#  [1040 1838]
#  [1024 1862]
#  [1044 1865]]EIGER_4MCdTeWriting .cor file in
#  Initial points:
#  nb of pixelsCCDLabel:
#  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0072.cor [[ 496    5]
#  [1027    9]
#  [1460   95]
#  ...
#  [1044 1865]
#  [1156 1892]
#  [1950 1935]](2162, 2068)EIGER_4MCdTe
#
# inbands
#
# inbands nb of pixelsin folder(68,) (2162, 2068)
# [[ 496    5]
#  [ 497    7]
#  [1027    8]
#  ...
#  [1024 1772]
#  [1041 1773]
#  [1044 1865]]
#  In convert2corfile():
# (63,)
#
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesIn convert2corfile():
#
# In convert2corfile():
# In convert2corfile()  at the end:
# Writing .cor file in  In convert2corfile()  at the end: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0065.cor
#
# in folderWriting .cor file in
# peak search progress bar::   1%|          | 213/27646 [00:10<54:06,  8.45it/s]
# In convert2corfile()  at the end:   /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0101.cor
# in folderInitial points:  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# [[ 497    7]
#  [1025   12]
#  [1555   20]
#  ...
#  [1588 1836]
#  [1044 1865]
#  [1950 1935]]
# Writing .cor file in
# Initial points:Initial points:   [[ 497    7]
#  [1025    6]
#  [1555    6]
#  ...
#  [1044 1865]
#  [1397 1911]
#  [1950 1935]]/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0111.cor[[ 497    7]
#  [1024    5]
#  [1025    7]
#  ...
#  [1044 1760]
#  [1040 1763]
#  [1044 1865]]
#
#
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# CCDLabel: inbands Initial points:(56,)
#   In convert2corfile(): [[ 497    7]
#  [1460   95]
#  [ 570   96]
#  ...
#  [1044 1865]
#  [1042 1872]
#  [1160 1887]]EIGER_4MCdTe
#
#
# nb of pixels (2162, 2068)
# In convert2corfile()  at the end:
# Writing .cor file in  CCDLabel: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_0102.cor
# in folder CCDLabel:  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfilesEIGER_4MCdTe
#
# nb of pixels EIGER_4MCdTe(2162, 2068)
# nb of pixels
#  (2162, 2068)
# inbands (51,)
# In convert2corfile(): inbands
#  (61,)
# In convert2corfile():
# In convert2corfile()  at the end:
# In convert2corfile()  at the end: Writing .cor file in
# ...
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   8%|▊         | 2229/27646 [22:26<2:47:05,  2.54it/s]
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# inbandsIn convert2corfile():  (260,)
#
# CCDLabel: Initial points: EIGER_4MCdTe
# [[ 512    0]
#  [1026    0]
#  [1549    0]
#  ...
#  [1839 2152]
#  [ 903 2153]
#  [ 902 2161]]nb of pixels (2162, 2068)
#
# inbands (234,)
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# In convert2corfile()  at the end:
# Writing .cor file in In convert2corfile():
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2098.cor
# in folderIn convert2corfile():  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# Initial points: [[1024    1]
#  [1551    1]
#  [ 516    2]
#  ...
#  [ 355 2151]
#  [ 354 2153]
#  [1716 2153]]
# Initial points: [[ 512    1]
#  [1025    2]
#  [1549    1]
#  ...
#  [1401 2147]
#  [1234 2149]
#  [ 427 2158]]
# Initial points: [[ 519    0]
#  [1024    2]
#  [ 512    2]
#  ...
#  [1022 2159]
#  [1807 2161]
#  [1024 2160]]
# In convert2corfile()  at the end:
# Writing .cor file in  In convert2corfile()  at the end: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2104.cor
#
# Writing .cor file in in folder  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2106.cor/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# Initial points: [[1024    0]
#  [ 512    1]
#  [1027    1]
#  ...
#  [1555 2107]
#  [1446 2108]
#  [1444 2109]]Initial points:
#  [[1027    0]
#  [1043    0]
#  [ 519    1]
#  ...
#  [1103 2158]
#  [ 292 2161]
#  [ 497 2161]]
# CCDLabel: Initial points:  [[1025    2]
#  [1551    1]
#  [ 512    4]
#  ...
#  [ 948 2150]
#  [1454 2150]
#  [1452 2151]]EIGER_4MCdTe
#
# nb of pixels (2162, 2068)
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# Initial points: [[1024    0]
#  [ 519    1]
#  [1024    3]
#  ...
#  [ 944 2137]
#  [ 941 2145]
#  [ 937 2150]]
# Initial points: [[1025    2]
#  [1027    0]
#  [ 512    1]
#  ...
#  [  37 2157]
#  [  33 2157]
#  [  32 2161]]
# Initial points: [[ 512    0]
#  [1025    0]
#  [1549    0]
#  ...
#  [1354 2159]
#  [1022 2160]
#  [1024 2161]]
# Initial points: inbands[[1024    1]
#  [1040    0]
#  [1026    1]
#  ...
#  [1025 2124]
#  [1416 2133]
#  [1095 2156]] (293,)
#
# Initial points: [[1024    0]
#  [1027    0]
#  [1044    1]
#  ...
#  [ 888 2157]
#  [1799 2158]
#  [ 574 2159]]
# In convert2corfile():
# Initial points: [[1024    1]
#  [ 512    2]
#  [ 518    3]
#  ...
#  [1063 2156]
#  [1060 2157]
#  [1062 2159]]
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2108.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   8%|▊         | 2233/27646 [22:32<4:56:31,  1.43it/s]
# inbands (271,)
# CCDLabel:  EIGER_4MCdTe
# nb of pixels In convert2corfile():
# (2162, 2068)
# Initial points: [[1026    5]
#  [1557    3]
#  [1549    4]
#  ...
#  [1027 2154]
#  [1024 2155]
#  [1065 2157]]
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2113.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# inbands (249,)
# In convert2corfile():
# Initial points: [[1024    1]
#  [1551    1]
#  [1026    1]
#  ...
#  [1009 2155]
#  [1333 2157]
#  [1022 2159]]
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2107.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# Initial points: [[1024    0]
#  [1026    3]
#  [1550    2]
#  ...
#  [ 940 2145]
#  [1592 2152]
#  [1043 2157]]
# inbandsCCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
#  (297,)
# inbandsInitial points: (307,)
# [[1026    0]
#  [1025    3]
#  [1040    2]
#  ...
#  [1661 2153]
#  [ 997 2154]
#  [ 537 2161]]
# CCDLabel:  EIGER_4MCdTe
# nb of pixels (2162, 2068)
# Initial points: inbands[[ 512    0]
#  [1550    0]
#  [ 510    2]
#  ...
#  [1552 2151]
#  [1778 2159]
#  [ 946 2161]]
#  (312,)
# inbandsIn convert2corfile():
# In convert2corfile():  (279,)Initial points:
#
#  [[ 518    0]
#  [1024    0]
#  [1024    3]
#  ...
#  [1346 2156]
#  [ 977 2158]
#  [ 975 2159]]
# In convert2corfile(): Initial points:
#  [[1025    0]
#  [ 518    2]
#  [1550    2]
#  ...
#  [ 598 2160]
#  [1585 2158]
#  [1108 2160]]
# In convert2corfile()  at the end: In convert2corfile():
# Writing .cor file in
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2111.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# In convert2corfile()  at the end:
# Writing .cor file in  /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2109.cor
# in folder /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
# peak search progress bar::   8%|▊         | 2237/27646 [22:37<6:14:54,  1.13it/s]
# inbands (292,)
# inbands (299,)
# In convert2corfile()  at the end:
# In convert2corfile()  at the end: Writing .cor file in
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2112.cor
# Writing .cor file in in folder  CCDLabel: /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles/eiger4m_2119.cor/data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles
#
# in folderEIGER_4MCdTe inbands
# /data/visitor/ma6758/bm32/20260312/PROCESSED_DATA/RAW_DATA/Al/Al_map2D/scan0006/corfiles nb of pixels
# (321,)
# (2162, 2068)
# CCDLabel:
# peak search progress bar::   8%|▊         | 2241/27646 [22:38<4:59:20,  1.41it/s]Process ForkPoolWorker-64:
# peak search progress bar::   8%|▊         | 2241/27646 [22:38<4:16:45,  1.65it/s]Process ForkPoolWorker-7:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-42:
# Traceback (most recent call last):
# Process ForkPoolWorker-47:
# Traceback (most recent call last):
# Process ForkPoolWorker-27:
# Traceback (most recent call last):
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-40:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-25:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-60:
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-61:
# Traceback (most recent call last):
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-51:
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-63:
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_315203/2665121856.py", line 66, in peaksearch_oneimage
#     res=RMCCD.PeakSearch(filename=pathfile,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_315203/2665121856.py", line 66, in peaksearch_oneimage
#     res=RMCCD.PeakSearch(filename=pathfile,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/data/bm32/inhouse/lauetoolsenv2/lib/python3.12/site-packages/LaueTools/readmccd.py", line 1508, in PeakSearch
#     return fitoneimage_manypeaks(filename,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 75
#      73 with multiprocessing.Pool(nbcpus) as pool:
#      74     if BUILD_ALLRESULTS_LIST:
# ---> 75         allresults = pool.starmap(peaksearch_oneimage, tqdm(args_peaksearch, total=len(listindices),
#      76                               desc='peak search progress bar:'), chunksize=1)
#      77     else:
#      78         pool.starmap(peaksearch_oneimage, tqdm(args_peaksearch, total=len(listindices),
#      79                               desc='peak search progress bar:'), chunksize=1)
#
# File /cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /cvmfs/hpc.esrf.fr/software/packages/linux/x86_64/jupyter-slurm/2025.04.5/envs/jupyter-slurm/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
import sys
print('size of object "allresults" =====> %.2f kb '%(sys.getsizeof(allresults)/1024.))

# %%
# allresults is a list. Each elem is a list: [0] image or file index, [1] nb of peaks [2:] spots properties
# allresults[15]

# %% [markdown]
# ## pickling results

# %%
# use genfolder to write output  results
import pickle

if 1: # SAVE
    dictresults={'listindices':listindices, 'datfilefolder':str(datfilefolder)}
    dictresults['allresults']=allresults
    with open(datfilefolder/'peaksprops.pickle', 'wb') as f:
        pickle.dump(dictresults, f)
        
if 0: #LOAD
    if input('Are you sure to load a previous file and overwrite current dictresults?') in ('y','yes','Y','YES','o','O'):
        with open(datfilefolder/'peaksprops.pickle', 'rb') as f:
            dictresults=pickle.load(f)
            allresults = dictresults['allresults']
            listindices = dictresults.get('listindices',None)
            datfilefolder = dictresults.get('datfilefolder', datfilefolder)
            
            if listindices is None:
                listindices=np.arange(len(allresults))
            
#print(datfilefolder, listindices, len(allresults))

# %% [markdown]
# # Visualisation

# %% [markdown]
# ## PLOT nb peaks

# %%
# for 2D map 

# BLISS motors command
# amesh fastaxis ... ... nbstepfast slowaxis ... ...  nbstepslow
# mapdims = (nbstepslow+1,nbstepfast+1)

if expId == '322812':
    mapdims = (17,17)  # slow axis,   fast axis

if expId == 'blc15488':
    mapdims = (51,61)  # slow axis,   fast axis

# -------  data building ---------------
nbpeaks_l = np.zeros(len(listindices))

for _k in np.arange(len(listindices)):
    nbpeaks_l[_k]=allresults[_k][1]
nbpeaks_array= np.array(nbpeaks_l) 

nbpeaks2D = nbpeaks_array.reshape(mapdims)

# -------------visualisation ------------------
fig, ax = plt.subplots()
ax.imshow(nbpeaks2D, origin='lower')
ax.set_xlabel('fastaxis index')
ax.set_ylabel('slowaxis index')
if 'RAW_DATA' in str(datfilefolder):
    s1, s2 = str.split(str(datfilefolder), 'RAW_DATA')
    titleax = '%s/RAW_DATA/\n%s'%(s1,s2)
else:
    titleax = datfilefolder
    
def format_getimageindex(x, y):
    col = int(x + 0.5)
    row = int(y + 0.5)
    if col >= 0 and col < mapdims[1] and row >= 0 and row < mapdims[0]:
        img_idx = 0+ mapdims[1]*row+col
        return "x=%1.4f, y=%1.4f, imageid=%d" % (x, y,img_idx)
    else:
        return "x=%1.4f, y=%1.4f" % (x, y)
ax.format_coord = format_getimageindex

ax.set_title('%s'%titleax)
# Out:
# Text(0.5, 1.0, '/home/micha/LaueTutorialsResults/peaksearch/ech15/ech15_map2Dexpo0p1sec/scan0001/corfiles')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# get sample map location of highest nb of peaks
fast_ix, slow_ix = np.argmax(nbpeaks2D)%mapdims[1], np.argmax(nbpeaks2D)//mapdims[1]
max_imageindex = slow_ix*mapdims[1]+fast_ix
max_nbpeaks = np.amax(nbpeaks2D)
print('max number of peaks is : %d'%max_nbpeaks)
print('at image : ', max_imageindex)
print('at scan position: fast_index, slow_index  :', fast_ix, slow_ix)
# Out:
# max number of peaks is : 1464
# at image :  740
# at scan position: fast_index, slow_index  : 8 12

# %% [markdown]
# ## PLOT peaks per image
#
# Build `allpeaksXY`  big array containing all peaks coordinates of the map

# %%
# build big array containing all peaks coordinates of the map
allpeakspos_l = -100*np.zeros((len(listindices),int(max_nbpeaks),2))

for _k in np.arange(len(listindices)):
    nbp = allresults[_k][1]
    if nbp > 1:
        pklist = np.array(allresults[_k][2:])
        _n = len(pklist)
        allpeakspos_l[_k][:_n]=pklist[:,:2]
allpeaksXY= np.array(allpeakspos_l)

# %%
# to see one element of `allpeaksXY`
if 0:
    local_index = 6
    fig, ax = plt.subplots()
    spots= allpeaksXY[local_index]
    ax.scatter(spots[:,0], spots[:,1])
    ax.set_xlim(0,2050)
    ax.set_ylim(2050,0)
    ax.set_title('Peaks: imageindex=%d'%listindices[local_index])

# %% [markdown]
# ### GUI PLOT peak list Browser

# %%
imageindex0 = 0  # initial value for the first plot

from ipywidgets import interact, interactive, fixed, interact_manual
fig, ax = plt.subplots()
spots= allpeaksXY[imageindex0]
ax.scatter(spots[:,0], spots[:,1])
ax.set_xlim(0,2000)
ax.set_ylim(2000,0)

def plotpeaks(imageindex=imageindex0, shownbpeaks=True, grid=False):
    ymin, ymax = ax.get_ylim()
    xmin, xmax = ax.get_xlim()
    ax.clear()
    ax.set_xlim(xmin, xmax)
    ax.set_ylim(ymin, ymax)
    
    spots= allpeaksXY[imageindex]
    print(len(spots))
    ax.scatter(spots[:,0], spots[:,1])
    if 'RAW_DATA' in str(datfilefolder):
        s1, s2 = str.split(str(datfilefolder), 'RAW_DATA')
        titleax = '%s/RAW_DATA/\n%s'%(s1,s2)
    else:
        titleax = str(datfilefolder)
    titleax +='\nimageindex=%d'%imageindex
    if shownbpeaks:
        titleax+='\nnbpeaks=%d'%len(spots[:,0])
    if grid:
        ax.grid()
    ax.set_title(titleax)

    
interactive(plotpeaks, imageindex=(0,max(listindices)-1), shownbpeaks=[True, False], grid=[False, True])
# Out:
# interactive(children=(IntSlider(value=0, description='imageindex', max=3109), Dropdown(description='shownbpeak…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# as others do, for small set of data: we could do pca or nmf to find main grains (see sergio)
# good for small number of grains
